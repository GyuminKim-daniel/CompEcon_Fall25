# %% [markdown]
# Exercise 14.1
#
# Install and run the OG-Core example file as instructed. How long did it take to execute?
#
# A: 700min 45 seconds

# %%
# !pip install --upgrade pip
# !pip install ogcore
import ogcore
ogcore.__version__

import os

project_dir = r"C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9"
os.makedirs(project_dir, exist_ok=True)

project_dir

from ogcore import execute
# %run run_ogcore_example.py
# Out:
# Requirement already satisfied: pip in c:\users\gyumin kim\anaconda3\lib\site-packages (25.1)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\Gyumin Kim\anaconda3\python.exe -m pip install --upgrade pip
# c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 64257 instead
#   warnings.warn(
# State start
#   Scheduler at:     tcp://127.0.0.1:64258
#   dashboard at:  http://127.0.0.1:64257/status
# Registering Worker plugin shuffle
#         Start Nanny at: 'tcp://127.0.0.1:64267'
#         Start Nanny at: 'tcp://127.0.0.1:64271'
#         Start Nanny at: 'tcp://127.0.0.1:64263'
#         Start Nanny at: 'tcp://127.0.0.1:64261'
#         Start Nanny at: 'tcp://127.0.0.1:64265'
#         Start Nanny at: 'tcp://127.0.0.1:64273'
#         Start Nanny at: 'tcp://127.0.0.1:64269'
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64267'. Reason: nanny-instantiate-failed
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64271'. Reason: nanny-instantiate-failed
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64263'. Reason: nanny-instantiate-failed
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64261'. Reason: nanny-instantiate-failed
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64265'. Reason: nanny-instantiate-failed
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64273'. Reason: nanny-instantiate-failed
# Failed to start process
# Traceback (most recent call last):
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 452, in instantiate
#     result = await self.process.start()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\nanny.py", line 750, in start
#     await self.process.start()
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 55, in _call_and_set_future
#     res = func(*args, **kwargs)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\process.py", line 215, in _start
#     process.start()
#     ~~~~~~~~~~~~~^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\process.py", line 121, in start
#     self._popen = self._Popen(self)
#                   ~~~~~~~~~~~^^^^^^
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\context.py", line 337, in _Popen
#     return Popen(process_obj)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\popen_spawn_win32.py", line 47, in __init__
#     prep_data = spawn.get_preparation_data(process_obj._name)
#   File "c:\Users\Gyumin Kim\anaconda3\Lib\multiprocessing\spawn.py", line 193, in get_preparation_data
#     main_mod_name = getattr(main_module.__spec__, "name", None)
#                             ^^^^^^^^^^^^^^^^^^^^
# AttributeError: module '__main__' has no attribute '__spec__'. Did you mean: '__doc__'?
# Closing Nanny at 'tcp://127.0.0.1:64269'. Reason: nanny-instantiate-failed
# Requirement already satisfied: ogcore in c:\users\gyumin kim\anaconda3\lib\site-packages (0.14.14)
# Requirement already satisfied: numpy in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (2.1.3)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (1.15.3)
# Requirement already satisfied: pandas>=1.2.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (2.2.3)
# Requirement already satisfied: numba in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (0.61.0)
# Requirement already satisfied: matplotlib in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (3.10.0)
# Requirement already satisfied: dask>=2.30.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (2025.2.0)
# Requirement already satisfied: distributed>=2.30.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (2025.2.0)
# Requirement already satisfied: paramtools>=0.20.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (0.20.0)
# Requirement already satisfied: requests in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (2.32.3)
# Requirement already satisfied: pip in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (25.1)
# Requirement already satisfied: pygam in c:\users\gyumin kim\anaconda3\lib\site-packages (from ogcore) (0.11.0)
# Requirement already satisfied: click>=8.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (8.1.8)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (24.2)
# Requirement already satisfied: partd>=1.4.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from dask>=2.30.0->ogcore) (1.0.0)
# Requirement already satisfied: colorama in c:\users\gyumin kim\anaconda3\lib\site-packages (from click>=8.1->dask>=2.30.0->ogcore) (0.4.6)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (3.1.6)
# Requirement already satisfied: locket>=1.0.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (1.0.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (5.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (2.3.0)
# Requirement already satisfied: zict>=3.0.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from distributed>=2.30.1->ogcore) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from jinja2>=2.10.3->distributed>=2.30.1->ogcore) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=1.2.5->ogcore) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=1.2.5->ogcore) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=1.2.5->ogcore) (2025.2)
# Requirement already satisfied: marshmallow>=4.0.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from paramtools>=0.20.0->ogcore) (4.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.5->ogcore) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from matplotlib->ogcore) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gyumin kim\anaconda3\lib\site-packages (from matplotlib->ogcore) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from matplotlib->ogcore) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from matplotlib->ogcore) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\gyumin kim\anaconda3\lib\site-packages (from matplotlib->ogcore) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from matplotlib->ogcore) (3.2.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from numba->ogcore) (0.44.0)
# Requirement already satisfied: progressbar2<5,>=4.2.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pygam->ogcore) (4.5.0)
# Requirement already satisfied: python-utils>=3.8.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from progressbar2<5,>=4.2.0->pygam->ogcore) (3.9.1)
# Requirement already satisfied: typing_extensions>3.10.0.2 in c:\users\gyumin kim\anaconda3\lib\site-packages (from python-utils>=3.8.1->progressbar2<5,>=4.2.0->pygam->ogcore) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests->ogcore) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests->ogcore) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests->ogcore) (2025.4.26)
# Number of workers =  7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\run_ogcore_example.py:138
#     133     client.close()
#     136 if __name__ == "__main__":
#     137     # execute only if run as a script
# --> 138     main()
#
# File ~\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\run_ogcore_example.py:29, in main()
#      27 num_workers = min(multiprocessing.cpu_count(), 7)
#      28 print("Number of workers = ", num_workers)
# ---> 29 client = Client(n_workers=num_workers, threads_per_worker=1)
#      31 # Directories to save data
#      32 CUR_DIR = os.path.dirname(os.path.realpath(__file__))
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\client.py:1230, in Client.__init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#    1227 preload_argv = dask.config.get("distributed.client.preload-argv")
#    1228 self.preloads = preloading.process_preloads(self, preload, preload_argv)
# -> 1230 self.start(timeout=timeout)
#    1231 Client._instances.add(self)
#    1233 from distributed.recreate_tasks import ReplayTaskClient
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\client.py:1432, in Client.start(self, **kwargs)
#    1430     self._started = asyncio.ensure_future(self._start(**kwargs))
#    1431 else:
# -> 1432     sync(self.loop, self._start, **kwargs)
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\utils.py:436, in sync(loop, func, callback_timeout, *args, **kwargs)
#     434 else:
#     435     while not e.is_set():
# --> 436         wait(10)
#     438 if error is not None:
#     439     raise error
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\distributed\utils.py:425, in sync.<locals>.wait(timeout)
#     423 def wait(timeout: float | None) -> bool:
#     424     try:
# --> 425         return e.wait(timeout)
#     426     except KeyboardInterrupt:
#     427         loop.add_callback(cancel)
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Exercise 15.1 : Using the above code blocks as an example, simulate the effects of a change in the corporate income tax rate (note the default in OG-Core is 21%). Just simulate the effects on the steady state (see the keyword arguments to the runner function). Warning: OG-Core allows the corporate income tax rate to vary over time and across industries, so you will need to enter it as a list of lists (even if it’s just a scalar that applies to all industries and time).

# %%
"""
Exercise 15.1 — Steady-State Effects of a Corporate Income Tax Change (OG-Core)
-------------------------------------------------------------------------------

This script performs the following steps:

1. Solve the *baseline* OG-Core steady state (with the default CIT rate = 21%).
2. Solve a *reform* steady state that changes the corporate income tax rate.
   - In OG-Core, the CIT rate must be entered as a list of lists,
     since the model allows time- and industry-varying CIT rates.
     For a single industry and time-invariant tax:
         cit_rate = [[new_rate]]
3. Load the steady-state variable dictionaries from the output folders.
4. Compare baseline vs. reform GDP (Y).

Notes:
 - time_path=False ensures that OG-Core computes ONLY the steady state,
   not the full transition path.
 - OUTPUT_BASELINE and OUTPUT_REFORM will contain SS results and logs.
"""

from ogcore.parameters import Specifications
from ogcore.execute import runner
from pathlib import Path
import pickle
import numpy as np

# --------------------------------------------------------
# 1. Baseline model (default CIT = 21%)
# --------------------------------------------------------
p_base = Specifications(
    baseline=True,
    output_base="./OUTPUT_BASELINE"
)

print("Solving baseline steady state...")
baseline_results = runner(p_base, time_path=False)
print("Baseline steady state complete.\n")

# --------------------------------------------------------
# 2. Reform model: Change CIT rate to 15%
#    IMPORTANT: OG-Core requires a list of lists for cit_rate
# --------------------------------------------------------
p_reform = Specifications(
    baseline=False,
    output_base="./OUTPUT_REFORM"
)

p_reform.update_specifications({
    "cit_rate": [[0.15]]   # 15% CIT rate
})

print("Solving reform steady state (CIT=15%)...")
reform_results = runner(p_reform, time_path=False)
print("Reform steady state complete.\n")

# --------------------------------------------------------
# 3. Load steady-state variable pickle files
# --------------------------------------------------------
ss_base_path = Path("./OUTPUT_BASELINE/SS/SS_vars.pkl")
ss_reform_path = Path("./OUTPUT_REFORM/SS/SS_vars.pkl")

with ss_base_path.open("rb") as f:
    ss_base = pickle.load(f)

with ss_reform_path.open("rb") as f:
    ss_reform = pickle.load(f)

# --------------------------------------------------------
# 4. Compare GDP (Y) between baseline and reform
# --------------------------------------------------------
Y_base = ss_base["Y"]
Y_reform = ss_reform["Y"]
pct_change = 100 * (Y_reform - Y_base) / Y_base

print("Baseline GDP:", Y_base)
print("Reform GDP:", Y_reform)
print(f"GDP % Change from CIT cut: {pct_change:.2f}%")
# Out:
# SS using initial guess factors for r and TR of 1.0 and 1.0 respectively.
# Solving baseline steady state...
# making dir:  ./OUTPUT_BASELINE\SS
# making dir:  ./OUTPUT_BASELINE\TPI
# In runner, baseline is  True
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '-1.490e-08', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['-7.776e-02', '-8.853e-02', '1.057e+00', '-2.220e-16', '1.158e-02', '-8.707e-04', '-6.208e-01', '6.336e-01', '-2.623e-01', '9.476e-01', '-5.198e-01', '7.732e-02', '1.042e-03', '6.444e-02']
# GE loop errors = ['-1.213e-01', '-1.325e-01', '2.196e+00', '-2.085e-03', '-1.567e-01', '4.654e-03', '1.997e-01', '-1.175e-01', '1.636e-01', '-2.364e-01', '3.285e-01', '-1.736e-02', '-1.410e-02', '5.672e-01']
# GE loop errors = ['-8.769e-02', '-9.082e-02', '1.593e+00', '0.000e+00', '-1.920e-01', '1.209e-02', '3.374e-02', '6.088e-02', '5.655e-02', '2.576e-02', '1.071e-01', '8.579e-03', '-1.728e-02', '3.747e-01']
# GE loop errors = ['-8.696e-02', '-9.008e-02', '1.546e+00', '0.000e+00', '-2.260e-01', '1.210e-02', '3.036e-02', '5.480e-02', '5.092e-02', '2.319e-02', '9.643e-02', '7.726e-03', '-2.034e-02', '3.770e-01']
# GE loop errors = ['-8.615e-02', '-8.926e-02', '1.497e+00', '0.000e+00', '-2.569e-01', '1.211e-02', '2.731e-02', '4.934e-02', '4.585e-02', '2.087e-02', '8.685e-02', '6.958e-03', '-2.312e-02', '3.798e-01']
# GE loop errors = ['-8.527e-02', '-8.836e-02', '1.446e+00', '-1.490e-08', '-2.848e-01', '1.212e-02', '2.457e-02', '4.442e-02', '4.129e-02', '1.879e-02', '7.822e-02', '6.266e-03', '-2.563e-02', '3.832e-01']
# GE loop errors = ['-8.430e-02', '-8.736e-02', '1.392e+00', '0.000e+00', '-3.102e-01', '1.213e-02', '2.211e-02', '3.999e-02', '3.719e-02', '1.691e-02', '7.046e-02', '5.644e-03', '-2.792e-02', '3.870e-01']
# GE loop errors = ['-8.324e-02', '-8.625e-02', '1.337e+00', '0.000e+00', '-3.334e-01', '1.214e-02', '1.989e-02', '3.601e-02', '3.349e-02', '1.523e-02', '6.347e-02', '5.084e-03', '-3.001e-02', '3.914e-01']
# GE loop errors = ['-8.207e-02', '-8.502e-02', '1.279e+00', '0.000e+00', '-3.545e-01', '1.216e-02', '1.789e-02', '3.242e-02', '3.017e-02', '1.371e-02', '5.718e-02', '4.580e-03', '-3.190e-02', '3.962e-01']
# GE loop errors = ['-8.080e-02', '-8.366e-02', '1.218e+00', '0.000e+00', '-3.738e-01', '1.217e-02', '1.609e-02', '2.919e-02', '2.717e-02', '1.234e-02', '5.152e-02', '4.126e-03', '-3.364e-02', '4.015e-01']
# GE loop errors = ['-7.940e-02', '-8.214e-02', '1.156e+00', '0.000e+00', '-3.914e-01', '1.219e-02', '1.447e-02', '2.629e-02', '2.448e-02', '1.111e-02', '4.642e-02', '3.717e-03', '-3.523e-02', '4.073e-01']
# GE loop errors = ['-7.787e-02', '-8.045e-02', '1.092e+00', '0.000e+00', '-4.076e-01', '1.221e-02', '1.301e-02', '2.367e-02', '2.205e-02', '1.000e-02', '4.183e-02', '3.350e-03', '-3.669e-02', '4.135e-01']
# GE loop errors = ['-7.618e-02', '-7.856e-02', '1.026e+00', '0.000e+00', '-4.225e-01', '1.223e-02', '1.170e-02', '2.131e-02', '1.987e-02', '9.006e-03', '3.770e-02', '3.019e-03', '-3.803e-02', '4.202e-01']
# GE loop errors = ['-7.433e-02', '-7.645e-02', '9.583e-01', '0.000e+00', '-4.363e-01', '1.226e-02', '1.052e-02', '1.919e-02', '1.790e-02', '8.108e-03', '3.398e-02', '2.721e-03', '-3.927e-02', '4.272e-01']
# GE loop errors = ['-7.230e-02', '-7.407e-02', '8.889e-01', '0.000e+00', '-4.491e-01', '1.228e-02', '9.456e-03', '1.729e-02', '1.613e-02', '7.300e-03', '3.064e-02', '2.452e-03', '-4.041e-02', '4.347e-01']
# GE loop errors = ['-7.006e-02', '-7.139e-02', '8.179e-01', '0.000e+00', '-4.609e-01', '1.231e-02', '8.499e-03', '1.557e-02', '1.454e-02', '6.572e-03', '2.763e-02', '2.211e-03', '-4.148e-02', '4.425e-01']
# GE loop errors = ['-4.441e-02', '-1.634e-01', '1.990e+00', '-1.080e-11', '-2.389e-01', '9.864e-03', '7.901e-03', '1.410e-02', '1.303e-02', '6.008e-03', '2.461e-02', '1.986e-03', '-2.150e-02', '4.948e-01']
# GE loop errors = ['-4.916e-02', '-1.340e-01', '1.842e+00', '-3.221e-11', '-4.677e-01', '9.471e-03', '7.005e-03', '1.267e-02', '1.176e-02', '5.391e-03', '2.229e-02', '1.798e-03', '-4.209e-02', '5.657e-01']
# GE loop errors = ['-4.801e-02', '-9.140e-02', '1.156e+00', '-3.694e-11', '-5.073e-01', '6.782e-03', '6.271e-03', '1.146e-02', '1.069e-02', '4.859e-03', '2.029e-02', '1.632e-03', '-4.566e-02', '4.676e-01']
# GE loop errors = ['-5.364e-02', '-6.827e-02', '6.912e-01', '-3.582e-11', '-4.789e-01', '1.046e-02', '5.582e-03', '1.028e-02', '9.615e-03', '4.342e-03', '1.829e-02', '1.465e-03', '-4.310e-02', '4.696e-01']
# GE loop errors = ['-5.262e-02', '-5.628e-02', '5.097e-01', '-4.008e-11', '-4.955e-01', '1.163e-02', '4.992e-03', '9.247e-03', '8.670e-03', '3.900e-03', '1.651e-02', '1.321e-03', '-4.459e-02', '4.811e-01']
# GE loop errors = ['-4.924e-02', '-4.704e-02', '3.901e-01', '-4.163e-11', '-5.109e-01', '1.214e-02', '4.474e-03', '8.329e-03', '7.825e-03', '3.509e-03', '1.492e-02', '1.193e-03', '-4.598e-02', '4.890e-01']
# GE loop errors = ['-4.239e-02', '-3.790e-02', '2.880e-01', '-4.236e-11', '-5.230e-01', '1.244e-02', '4.022e-03', '7.525e-03', '7.081e-03', '3.168e-03', '1.351e-02', '1.080e-03', '-4.707e-02', '4.773e-01']
# GE loop errors = ['-3.352e-02', '-2.761e-02', '1.915e-01', '-4.270e-11', '-5.330e-01', '1.266e-02', '3.621e-03', '6.809e-03', '6.418e-03', '2.864e-03', '1.226e-02', '9.795e-04', '-4.797e-02', '4.600e-01']
# SS using initial guess factors for r and TR of 0.95 and 1.0 respectively.
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '-1.490e-08', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['-9.275e-03', '-9.646e-03', '4.485e-02', '0.000e+00', '-2.508e-02', '3.601e-02', '3.617e-02', '3.619e-02', '1.831e-02', '1.107e-03', '7.557e-02', '4.605e-03', '-2.257e-03', '5.732e-03']
# GE loop errors = ['-7.891e-04', '4.148e-03', '-1.511e-02', '-3.304e-03', '6.562e-03', '1.687e-02', '1.968e-02', '2.072e-02', '9.424e-03', '3.704e-03', '3.164e-02', '-3.428e-04', '5.906e-04', '-1.645e-02']
# GE loop errors = ['-8.341e-04', '-8.789e-04', '6.386e-03', '0.000e+00', '-3.810e-03', '9.368e-03', '9.379e-03', '9.290e-03', '4.714e-03', '7.052e-05', '1.906e-02', '1.117e-03', '-3.429e-04', '9.652e-04']
# GE loop errors = ['1.084e-04', '1.131e-04', '-4.893e-04', '0.000e+00', '-2.365e-04', '5.476e-03', '5.467e-03', '5.530e-03', '2.710e-03', '-4.892e-05', '1.113e-02', '7.110e-04', '-2.128e-05', '3.138e-05']
# GE loop errors = ['2.961e-04', '3.031e-04', '-2.917e-04', '0.000e+00', '7.375e-04', '-1.965e-04', '-1.843e-04', '-2.036e-04', '-8.413e-05', '3.720e-05', '-3.947e-04', '-1.912e-05', '6.637e-05', '-5.759e-05']
# GE loop errors = ['2.162e-05', '2.186e-05', '3.510e-05', '0.000e+00', '-3.993e-05', '9.701e-05', '9.680e-05', '9.620e-05', '4.851e-05', '-1.164e-06', '1.928e-04', '1.116e-05', '-3.593e-06', '9.077e-06']
# GE loop errors = ['8.407e-06', '8.551e-06', '3.198e-06', '0.000e+00', '-6.216e-06', '2.687e-05', '2.689e-05', '2.690e-05', '1.352e-05', '1.303e-08', '5.377e-05', '3.143e-06', '-5.595e-07', '1.433e-06']
# GE loop errors = ['2.950e-07', '2.993e-07', '2.758e-07', '0.000e+00', '-5.907e-08', '3.486e-07', '3.503e-07', '3.315e-07', '1.789e-07', '2.851e-09', '6.889e-07', '3.830e-08', '-5.316e-09', '6.088e-08']
# GE loop errors = ['1.981e-08', '2.018e-08', '2.422e-10', '0.000e+00', '-2.442e-08', '7.272e-08', '7.279e-08', '7.386e-08', '3.659e-08', '3.946e-10', '1.464e-07', '8.629e-09', '-2.198e-09', '2.250e-09']
# GE loop errors = ['-6.032e-09', '-6.146e-09', '1.588e-10', '0.000e+00', '7.300e-09', '-2.312e-08', '-2.314e-08', '-2.349e-08', '-1.163e-08', '-1.139e-10', '-4.654e-08', '-2.749e-09', '6.570e-10', '-6.672e-10']
# GE loop errors = ['2.004e-11', '2.039e-11', '6.033e-12', '0.000e+00', '-3.192e-11', '4.741e-11', '4.750e-11', '4.840e-11', '2.401e-11', '6.549e-13', '9.593e-11', '5.526e-12', '-2.873e-12', '2.663e-12']
# GE loop errors = ['7.674e-13', '7.807e-13', '2.609e-13', '0.000e+00', '-1.249e-12', '1.562e-12', '1.566e-12', '1.597e-12', '7.933e-13', '2.793e-14', '3.168e-12', '1.814e-13', '-1.124e-13', '1.009e-13']
# Iteration: 1  Distance: 1.0391492421634068e-10
# SS debt = 1.2067673185280094, 0.015342656492163374
# IO: (1, 1), C: (1,)
# Foreign debt holdings = 0.4827069274112038
# Foreign capital holdings = 0.08516430154921899
# resource constraint: [-1.64278313e-13]
# Steady state government spending is negative to satisfy budget
# Checking constraints on capital, labor, and consumption.
# There were no violations of the constraints on labor supply.
# There were no violations of the constraints on consumption.
# Maximum error in labor FOC = 1.474376176702208e-13
# Maximum error in savings FOC = 1.0125233984581428e-13
# c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\SS.py:1568: UserWarning: Warning: The combination of the tax policy you specified and your target debt-to-GDP ratio results in an infeasible amount of government spending in order to close the budget (i.e., G < 0)
#   warnings.warn(
# JUST SAVED SS output to  ./OUTPUT_BASELINE\SS\SS_vars.pkl
# It took 101.74375128746033 seconds to get that part done.
# Baseline steady state complete.
# Using previous solutions for SS
# Solving reform steady state (CIT=15%)...
# making dir:  ./OUTPUT_REFORM\SS
# making dir:  ./OUTPUT_REFORM\TPI
# In runner, baseline is  False
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.798e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '-1.490e-08', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['7.932e-04', '7.881e-04', '6.735e-04', '0.000e+00', '3.450e-04', '1.067e-05', '1.459e-05', '1.606e-05', '9.797e-06', '1.160e-05', '1.375e-05', '2.688e-06', '3.105e-05']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['2.630e-09', '2.692e-09', '-1.581e-09', '0.000e+00', '-5.239e-10', '1.609e-10', '1.128e-05', '-1.128e-05', '1.047e-10', '1.189e-10', '2.255e-05', '-1.409e-06', '-4.715e-11']
# GE loop errors = ['-4.415e-08', '-4.517e-08', '2.254e-08', '0.000e+00', '7.853e-09', '-2.856e-09', '1.129e-05', '-1.129e-05', '-1.876e-09', '-2.132e-09', '2.258e-05', '-1.412e-06', '7.068e-10']
# GE loop errors = ['1.067e-06', '1.077e-06', '3.329e-06', '0.000e+00', '7.212e-07', '2.224e-07', '1.122e-05', '-1.066e-05', '1.616e-07', '1.851e-07', '2.213e-05', '-1.309e-06', '6.491e-08']
# GE loop errors = ['1.069e-06', '1.077e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.068e-06', '1.077e-06', '3.312e-06', '0.000e+00', '7.224e-07', '2.224e-07', '1.122e-05', '-1.066e-05', '1.616e-07', '1.851e-07', '2.213e-05', '-1.309e-06', '6.502e-08']
# GE loop errors = ['1.071e-06', '1.080e-06', '3.340e-06', '-1.490e-08', '7.291e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.562e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.222e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.613e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.848e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.325e-06', '0.000e+00', '7.198e-07', '2.223e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.478e-08']
# GE loop errors = ['1.069e-06', '1.078e-06', '3.324e-06', '0.000e+00', '7.096e-07', '2.224e-07', '1.122e-05', '-1.066e-05', '1.615e-07', '1.850e-07', '2.213e-05', '-1.309e-06', '6.387e-08']
# GE loop errors = ['1.361e-10', '1.405e-10', '-3.804e-10', '0.000e+00', '2.276e-09', '4.607e-12', '-5.363e-12', '7.788e-11', '3.388e-12', '3.223e-12', '7.019e-11', '9.253e-12', '2.048e-10']
# GE loop errors = ['3.185e-15', '3.247e-15', '-2.220e-15', '0.000e+00', '2.043e-14', '-5.759e-16', '1.058e-15', '-2.411e-15', '-3.105e-16', '-3.365e-16', '3.313e-15', '-2.724e-16', '1.846e-15']
# GE loop errors = ['-1.249e-16', '-1.249e-16', '1.554e-15', '0.000e+00', '6.661e-16', '-8.674e-18', '-1.041e-17', '1.735e-17', '1.388e-17', '-5.204e-18', '1.041e-17', '2.602e-18', '5.551e-17']
# Iteration: 1  Distance: 1.3829260174003307e-15
# SS debt = 1.2091249618053121, 0.015372631210884492
# IO: (1, 1), C: (1,)
# Foreign debt holdings = 0.4836499847221249
# Foreign capital holdings = 0.08667271505745017
# resource constraint: [-2.27873276e-14]
# Steady state government spending is negative to satisfy budget
# Checking constraints on capital, labor, and consumption.
# There were no violations of the constraints on labor supply.
# There were no violations of the constraints on consumption.
# Maximum error in labor FOC = 1.5054624213917123e-13
# Maximum error in savings FOC = 8.459899447643693e-14
# JUST SAVED SS output to  ./OUTPUT_REFORM\SS\SS_vars.pkl
# It took 37.93863916397095 seconds to get that part done.
# Reform steady state complete.
#
# Baseline GDP: 0.6033836592640047
# Reform GDP: 0.6045624809026561
# GDP % Change from CIT cut: 0.20%

# %% [markdown]
# Exercies 16.1 : Solve for the steady state of the model with the default value for the rate of time preferences. Then solve for the steady-state solution with (remembering to save the output in a different location than your baseline simulation). Use the ogcore.output_plots.ss_profiles function to plot savings by age over agents lifetimes before and after the change in the rate of time preference. What do you notice happens to savings?

# %%
"""
Exercise 16.1 — Effect of Changing the Discount Factor β on Steady-State Savings
--------------------------------------------------------------------------------

This script solves two steady states in OG-Core:

1. Baseline:
   - Uses default household discount factor beta_annual.

2. Reform:
   - Changes the rate of time preference by modifying beta_annual.
   - A lower beta_annual makes households more impatient and reduces savings.
   - A higher beta_annual makes households more patient and increases savings.

After solving the two steady states, the script loads the saved SS variables
and uses ogcore.output_plots.ss_profiles to plot lifetime savings profiles
(b_{s+1,j}) for each ability type j.

IMPORTANT:
- OG-Core stores savings as **"b_sp1"** (the assets chosen at age s and held at s+1).
- ss_profiles() must be called with var="b_sp1" to show savings.
"""

import ogcore
from ogcore.parameters import Specifications
from ogcore import execute
from ogcore.output_plots import ss_profiles

import numpy as np
import pickle
from pathlib import Path
import copy

# ------------------------------------------------
# Working directories
# ------------------------------------------------
BASE = Path("C:/Users/Gyumin Kim/Desktop/Coursework/25-2R/Computational Methods for Economists/Problemset9")
BASE.mkdir(exist_ok=True)

OUT_BASELINE = BASE / "OUTPUT_BASELINE"
OUT_REFORM   = BASE / "OUTPUT_REFORM"

OUT_BASELINE.mkdir(exist_ok=True)
OUT_REFORM.mkdir(exist_ok=True)

# ------------------------------------------------
# 1. Baseline steady state
# ------------------------------------------------
p_base = Specifications(
    baseline=True,
    output_base=str(OUT_BASELINE),
    baseline_dir=str(OUT_BASELINE)
)

print("Running baseline steady state...")
execute.runner(
    p_base,
    time_path=False
)
print("Baseline SS complete.")

# ------------------------------------------------
# 2. Reform steady state — change β (beta_annual)
# ------------------------------------------------
p_reform = copy.deepcopy(p_base)

# Example: make households more impatient (β = 0.90)
p_reform.beta_annual = 0.90

# Reform flags
p_reform.baseline = False
p_reform.output_base = str(OUT_REFORM)
p_reform.baseline_dir = str(OUT_BASELINE)

print("Running reform steady state with new beta_annual...")
execute.runner(
    p_reform,
    time_path=False
)
print("Reform SS complete.")

# ------------------------------------------------
# 3. Load SS variables
# ------------------------------------------------
with open(OUT_BASELINE / "SS/SS_vars.pkl", "rb") as f:
    ss_vars_base = pickle.load(f)

with open(OUT_REFORM / "SS/SS_vars.pkl", "rb") as f:
    ss_vars_reform = pickle.load(f)

# ------------------------------------------------
# 4. Plot savings profiles using ss_profiles
# ------------------------------------------------
fig = ss_profiles(
    ss_vars_base, p_base,
    ss_vars_reform, p_reform,
    var="b_sp1",
    by_j=False
)
# Out:
# SS using initial guess factors for r and TR of 1.0 and 1.0 respectively.
# Running baseline steady state...
# making dir:  C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OUTPUT_BASELINE\SS
# making dir:  C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OUTPUT_BASELINE\TPI
# In runner, baseline is  True
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '-1.490e-08', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['-7.776e-02', '-8.853e-02', '1.057e+00', '-2.220e-16', '1.158e-02', '-8.707e-04', '-6.208e-01', '6.336e-01', '-2.623e-01', '9.476e-01', '-5.198e-01', '7.732e-02', '1.042e-03', '6.444e-02']
# GE loop errors = ['-1.213e-01', '-1.325e-01', '2.196e+00', '-2.085e-03', '-1.567e-01', '4.654e-03', '1.997e-01', '-1.175e-01', '1.636e-01', '-2.364e-01', '3.285e-01', '-1.736e-02', '-1.410e-02', '5.672e-01']
# GE loop errors = ['-8.769e-02', '-9.082e-02', '1.593e+00', '0.000e+00', '-1.920e-01', '1.209e-02', '3.374e-02', '6.088e-02', '5.655e-02', '2.576e-02', '1.071e-01', '8.579e-03', '-1.728e-02', '3.747e-01']
# GE loop errors = ['-8.696e-02', '-9.008e-02', '1.546e+00', '0.000e+00', '-2.260e-01', '1.210e-02', '3.036e-02', '5.480e-02', '5.092e-02', '2.319e-02', '9.643e-02', '7.726e-03', '-2.034e-02', '3.770e-01']
# GE loop errors = ['-8.615e-02', '-8.926e-02', '1.497e+00', '0.000e+00', '-2.569e-01', '1.211e-02', '2.731e-02', '4.934e-02', '4.585e-02', '2.087e-02', '8.685e-02', '6.958e-03', '-2.312e-02', '3.798e-01']
# GE loop errors = ['-8.527e-02', '-8.836e-02', '1.446e+00', '-1.490e-08', '-2.848e-01', '1.212e-02', '2.457e-02', '4.442e-02', '4.129e-02', '1.879e-02', '7.822e-02', '6.266e-03', '-2.563e-02', '3.832e-01']
# GE loop errors = ['-8.430e-02', '-8.736e-02', '1.392e+00', '0.000e+00', '-3.102e-01', '1.213e-02', '2.211e-02', '3.999e-02', '3.719e-02', '1.691e-02', '7.046e-02', '5.644e-03', '-2.792e-02', '3.870e-01']
# GE loop errors = ['-8.324e-02', '-8.625e-02', '1.337e+00', '0.000e+00', '-3.334e-01', '1.214e-02', '1.989e-02', '3.601e-02', '3.349e-02', '1.523e-02', '6.347e-02', '5.084e-03', '-3.001e-02', '3.914e-01']
# GE loop errors = ['-8.207e-02', '-8.502e-02', '1.279e+00', '0.000e+00', '-3.545e-01', '1.216e-02', '1.789e-02', '3.242e-02', '3.017e-02', '1.371e-02', '5.718e-02', '4.580e-03', '-3.190e-02', '3.962e-01']
# GE loop errors = ['-8.080e-02', '-8.366e-02', '1.218e+00', '0.000e+00', '-3.738e-01', '1.217e-02', '1.609e-02', '2.919e-02', '2.717e-02', '1.234e-02', '5.152e-02', '4.126e-03', '-3.364e-02', '4.015e-01']
# GE loop errors = ['-7.940e-02', '-8.214e-02', '1.156e+00', '0.000e+00', '-3.914e-01', '1.219e-02', '1.447e-02', '2.629e-02', '2.448e-02', '1.111e-02', '4.642e-02', '3.717e-03', '-3.523e-02', '4.073e-01']
# GE loop errors = ['-7.787e-02', '-8.045e-02', '1.092e+00', '0.000e+00', '-4.076e-01', '1.221e-02', '1.301e-02', '2.367e-02', '2.205e-02', '1.000e-02', '4.183e-02', '3.350e-03', '-3.669e-02', '4.135e-01']
# GE loop errors = ['-7.618e-02', '-7.856e-02', '1.026e+00', '0.000e+00', '-4.225e-01', '1.223e-02', '1.170e-02', '2.131e-02', '1.987e-02', '9.006e-03', '3.770e-02', '3.019e-03', '-3.803e-02', '4.202e-01']
# GE loop errors = ['-7.433e-02', '-7.645e-02', '9.583e-01', '0.000e+00', '-4.363e-01', '1.226e-02', '1.052e-02', '1.919e-02', '1.790e-02', '8.108e-03', '3.398e-02', '2.721e-03', '-3.927e-02', '4.272e-01']
# GE loop errors = ['-7.230e-02', '-7.407e-02', '8.889e-01', '0.000e+00', '-4.491e-01', '1.228e-02', '9.456e-03', '1.729e-02', '1.613e-02', '7.300e-03', '3.064e-02', '2.452e-03', '-4.041e-02', '4.347e-01']
# GE loop errors = ['-7.006e-02', '-7.139e-02', '8.179e-01', '0.000e+00', '-4.609e-01', '1.231e-02', '8.499e-03', '1.557e-02', '1.454e-02', '6.572e-03', '2.763e-02', '2.211e-03', '-4.148e-02', '4.425e-01']
# GE loop errors = ['-4.441e-02', '-1.634e-01', '1.990e+00', '-1.080e-11', '-2.389e-01', '9.864e-03', '7.901e-03', '1.410e-02', '1.303e-02', '6.008e-03', '2.461e-02', '1.986e-03', '-2.150e-02', '4.948e-01']
# GE loop errors = ['-4.916e-02', '-1.340e-01', '1.842e+00', '-3.221e-11', '-4.677e-01', '9.471e-03', '7.005e-03', '1.267e-02', '1.176e-02', '5.391e-03', '2.229e-02', '1.798e-03', '-4.209e-02', '5.657e-01']
# GE loop errors = ['-4.801e-02', '-9.140e-02', '1.156e+00', '-3.694e-11', '-5.073e-01', '6.782e-03', '6.271e-03', '1.146e-02', '1.069e-02', '4.859e-03', '2.029e-02', '1.632e-03', '-4.566e-02', '4.676e-01']
# GE loop errors = ['-5.364e-02', '-6.827e-02', '6.912e-01', '-3.582e-11', '-4.789e-01', '1.046e-02', '5.582e-03', '1.028e-02', '9.615e-03', '4.342e-03', '1.829e-02', '1.465e-03', '-4.310e-02', '4.696e-01']
# GE loop errors = ['-5.262e-02', '-5.628e-02', '5.097e-01', '-4.008e-11', '-4.955e-01', '1.163e-02', '4.992e-03', '9.247e-03', '8.670e-03', '3.900e-03', '1.651e-02', '1.321e-03', '-4.459e-02', '4.811e-01']
# GE loop errors = ['-4.924e-02', '-4.704e-02', '3.901e-01', '-4.163e-11', '-5.109e-01', '1.214e-02', '4.474e-03', '8.329e-03', '7.825e-03', '3.509e-03', '1.492e-02', '1.193e-03', '-4.598e-02', '4.890e-01']
# GE loop errors = ['-4.239e-02', '-3.790e-02', '2.880e-01', '-4.236e-11', '-5.230e-01', '1.244e-02', '4.022e-03', '7.525e-03', '7.081e-03', '3.168e-03', '1.351e-02', '1.080e-03', '-4.707e-02', '4.773e-01']
# GE loop errors = ['-3.352e-02', '-2.761e-02', '1.915e-01', '-4.270e-11', '-5.330e-01', '1.266e-02', '3.621e-03', '6.809e-03', '6.418e-03', '2.864e-03', '1.226e-02', '9.795e-04', '-4.797e-02', '4.600e-01']
# SS using initial guess factors for r and TR of 0.95 and 1.0 respectively.
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '-1.490e-08', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['-9.275e-03', '-9.646e-03', '4.485e-02', '0.000e+00', '-2.508e-02', '3.601e-02', '3.617e-02', '3.619e-02', '1.831e-02', '1.107e-03', '7.557e-02', '4.605e-03', '-2.257e-03', '5.732e-03']
# GE loop errors = ['-7.891e-04', '4.148e-03', '-1.511e-02', '-3.304e-03', '6.562e-03', '1.687e-02', '1.968e-02', '2.072e-02', '9.424e-03', '3.704e-03', '3.164e-02', '-3.428e-04', '5.906e-04', '-1.645e-02']
# GE loop errors = ['-8.341e-04', '-8.789e-04', '6.386e-03', '0.000e+00', '-3.810e-03', '9.368e-03', '9.379e-03', '9.290e-03', '4.714e-03', '7.052e-05', '1.906e-02', '1.117e-03', '-3.429e-04', '9.652e-04']
# GE loop errors = ['1.084e-04', '1.131e-04', '-4.893e-04', '0.000e+00', '-2.365e-04', '5.476e-03', '5.467e-03', '5.530e-03', '2.710e-03', '-4.892e-05', '1.113e-02', '7.110e-04', '-2.128e-05', '3.138e-05']
# GE loop errors = ['2.961e-04', '3.031e-04', '-2.917e-04', '0.000e+00', '7.375e-04', '-1.965e-04', '-1.843e-04', '-2.036e-04', '-8.413e-05', '3.720e-05', '-3.947e-04', '-1.912e-05', '6.637e-05', '-5.759e-05']
# GE loop errors = ['2.162e-05', '2.186e-05', '3.510e-05', '0.000e+00', '-3.993e-05', '9.701e-05', '9.680e-05', '9.620e-05', '4.851e-05', '-1.164e-06', '1.928e-04', '1.116e-05', '-3.593e-06', '9.077e-06']
# GE loop errors = ['8.407e-06', '8.551e-06', '3.198e-06', '0.000e+00', '-6.216e-06', '2.687e-05', '2.689e-05', '2.690e-05', '1.352e-05', '1.303e-08', '5.377e-05', '3.143e-06', '-5.595e-07', '1.433e-06']
# GE loop errors = ['2.950e-07', '2.993e-07', '2.758e-07', '0.000e+00', '-5.907e-08', '3.486e-07', '3.503e-07', '3.315e-07', '1.789e-07', '2.851e-09', '6.889e-07', '3.830e-08', '-5.316e-09', '6.088e-08']
# GE loop errors = ['1.981e-08', '2.018e-08', '2.422e-10', '0.000e+00', '-2.442e-08', '7.272e-08', '7.279e-08', '7.386e-08', '3.659e-08', '3.946e-10', '1.464e-07', '8.629e-09', '-2.198e-09', '2.250e-09']
# GE loop errors = ['-6.032e-09', '-6.146e-09', '1.588e-10', '0.000e+00', '7.300e-09', '-2.312e-08', '-2.314e-08', '-2.349e-08', '-1.163e-08', '-1.139e-10', '-4.654e-08', '-2.749e-09', '6.570e-10', '-6.672e-10']
# GE loop errors = ['2.004e-11', '2.039e-11', '6.033e-12', '0.000e+00', '-3.192e-11', '4.741e-11', '4.750e-11', '4.840e-11', '2.401e-11', '6.549e-13', '9.593e-11', '5.526e-12', '-2.873e-12', '2.663e-12']
# GE loop errors = ['7.674e-13', '7.807e-13', '2.609e-13', '0.000e+00', '-1.249e-12', '1.562e-12', '1.566e-12', '1.597e-12', '7.933e-13', '2.793e-14', '3.168e-12', '1.814e-13', '-1.124e-13', '1.009e-13']
# Iteration: 1  Distance: 1.0391492421634068e-10
# SS debt = 1.2067673185280094, 0.015342656492163374
# IO: (1, 1), C: (1,)
# Foreign debt holdings = 0.4827069274112038
# Foreign capital holdings = 0.08516430154921899
# resource constraint: [-1.64278313e-13]
# Steady state government spending is negative to satisfy budget
# Checking constraints on capital, labor, and consumption.
# There were no violations of the constraints on labor supply.
# There were no violations of the constraints on consumption.
# Maximum error in labor FOC = 1.474376176702208e-13
# Maximum error in savings FOC = 1.0125233984581428e-13
# JUST SAVED SS output to  C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OUTPUT_BASELINE\SS\SS_vars.pkl
# It took 100.65424680709839 seconds to get that part done.
# Baseline SS complete.
# Running reform steady state with new beta_annual...
# making dir:  C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OUTPUT_REFORM\SS
# Using previous solutions for SS
# making dir:  C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OUTPUT_REFORM\TPI
# In runner, baseline is  False
# GE loop errors = ['-2.055e-12', '-2.147e-12', '1.217e-11', '0.000e+00', '5.119e-13', '2.867e-13', '3.037e-13', '2.945e-13', '1.581e-13', '7.350e-14', '4.780e-13', '4.451e-14', '4.607e-14']
# GE loop errors = ['-2.055e-12', '-2.147e-12', '1.217e-11', '0.000e+00', '5.120e-13', '2.867e-13', '3.037e-13', '2.945e-13', '1.581e-13', '7.350e-14', '4.780e-13', '4.451e-14', '4.608e-14']
# GE loop errors = ['-2.055e-12', '-2.147e-12', '1.217e-11', '0.000e+00', '5.120e-13', '2.867e-13', '3.037e-13', '2.945e-13', '1.581e-13', '7.350e-14', '4.780e-13', '4.451e-14', '4.608e-14']
# GE loop errors = ['-1.468e-09', '-6.793e-10', '3.851e-09', '0.000e+00', '1.412e-09', '1.073e-10', '1.425e-10', '1.417e-10', '8.394e-11', '9.734e-11', '1.336e-10', '2.993e-11', '1.271e-10']
# GE loop errors = ['-2.055e-12', '-9.387e-10', '1.217e-11', '0.000e+00', '5.120e-13', '2.867e-13', '3.037e-13', '2.945e-13', '1.581e-13', '7.350e-14', '4.780e-13', '4.451e-14', '4.608e-14']
# GE loop errors = ['-7.894e-10', '-8.248e-10', '-1.288e-08', '0.000e+00', '2.596e-09', '1.026e-10', '1.555e-10', '1.832e-10', '1.037e-10', '1.277e-10', '1.604e-10', '3.130e-11', '2.336e-10']
# GE loop errors = ['1.964e-09', '2.052e-09', '1.537e-08', '-1.490e-08', '9.210e-09', '-1.770e-11', '-2.175e-11', '-2.021e-11', '-1.325e-11', '-1.490e-11', '-1.853e-11', '-4.019e-12', '8.289e-10']
# GE loop errors = ['-2.055e-12', '-2.147e-12', '1.217e-11', '0.000e+00', '5.120e-13', '2.867e-13', '3.037e-13', '2.945e-13', '1.581e-13', '7.350e-14', '4.780e-13', '4.451e-14', '4.608e-14']
# GE loop errors = ['-3.573e-11', '-3.733e-11', '2.116e-10', '0.000e+00', '-2.554e-12', '-1.835e-10', '-3.157e-13', '-3.875e-13', '-2.578e-13', '-4.188e-13', '-1.059e-13', '-6.964e-14', '-2.298e-13']
# GE loop errors = ['-4.740e-11', '-4.952e-11', '2.807e-10', '0.000e+00', '-1.641e-11', '-3.234e-13', '-2.530e-10', '-6.236e-13', '-4.019e-13', '-5.893e-13', '-3.082e-13', '-1.092e-13', '-1.477e-12']
# GE loop errors = ['-5.241e-11', '-5.475e-11', '3.104e-10', '0.000e+00', '-3.109e-11', '-3.908e-13', '-6.223e-13', '-2.809e-10', '-4.638e-13', '-6.626e-13', '-3.951e-13', '-1.262e-13', '-2.798e-12']
# GE loop errors = ['-3.347e-11', '-3.496e-11', '1.982e-10', '0.000e+00', '-2.451e-11', '-1.359e-13', '-2.740e-13', '-3.416e-13', '-1.705e-10', '-3.857e-13', '-6.662e-14', '-6.195e-14', '-2.205e-12']
# GE loop errors = ['-3.936e-11', '-4.112e-11', '2.331e-10', '0.000e+00', '-3.453e-11', '-2.153e-13', '-3.824e-13', '-4.610e-13', '-3.027e-13', '-2.026e-10', '-1.689e-13', '-8.194e-14', '-3.108e-12']
# GE loop errors = ['-4.478e-11', '-4.679e-11', '2.652e-10', '0.000e+00', '-5.018e-11', '-2.883e-13', '-4.822e-13', '-5.708e-13', '-3.697e-13', '-5.512e-13', '-2.403e-10', '-1.003e-13', '-4.516e-12']
# GE loop errors = ['-1.005e-11', '-1.050e-11', '5.953e-11', '0.000e+00', '-1.417e-11', '1.791e-13', '1.566e-13', '1.326e-13', '5.936e-14', '-4.340e-14', '3.394e-13', '-4.705e-11', '-1.275e-12']
# GE loop errors = ['2.409e-10', '2.517e-10', '-1.427e-09', '0.000e+00', '-1.019e-08', '3.055e-11', '3.043e-11', '2.462e-11', '1.313e-11', '1.336e-11', '1.337e-11', '1.811e-12', '-9.168e-10']
# GE loop errors = ['3.469e-17', '4.163e-17', '-4.441e-16', '0.000e+00', '-1.110e-16', '-5.204e-18', '-1.080e-10', '1.080e-10', '-1.735e-18', '-8.674e-18', '-1.080e-10', '1.350e-11', '-6.939e-18']
# Iteration: 1  Distance: 2.2463982862357144e-11
# SS debt = 1.2067673185290335, 0.015342656492176393
# IO: (1, 1), C: (1,)
# Foreign debt holdings = 0.4827069274116134
# Foreign capital holdings = 0.08516430154265364
# resource constraint: [3.51281504e-14]
# Steady state government spending is negative to satisfy budget
# Checking constraints on capital, labor, and consumption.
# There were no violations of the constraints on labor supply.
# There were no violations of the constraints on consumption.
# Maximum error in labor FOC = 1.5187850976872141e-13
# Maximum error in savings FOC = 9.059419880941277e-14
# JUST SAVED SS output to  C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OUTPUT_REFORM\SS\SS_vars.pkl
# It took 19.565664291381836 seconds to get that part done.
# Reform SS complete.

# %% [markdown]
# Answers 16.1 : What do you notice happens to savings?
# When β is reduced (households become more impatient), savings fall slightly at all ages, with the largest declines among higher ability types and near retirement ages. What I expected is that the reform profiles lie consistently below baseline profiles, reflecting reduced willingness to sacrifice current consumption for future consumption. Frankly speaking, I cannot tell the difference between the baseline and reform.

# %% [markdown]
# Exercise 16.2 Take TPI output from https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/TPI_vars_baseline.pkl and convert the GDP series to constant units of local currency using the factor_ss and the growth rates, g_n and g_y . You can find the factor_ss in the steady state output at https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/SS_vars_baseline.pkl and the growth rates in the parameters file at https://github.com/PSLmodels/OG-Core/blob/master/tests/test_io_data/model_params_baseline.pk Hint: you can look at the OG-Core chapter on stationarizing the model to help see how to get back to non-stationary measures.

# %%
"""
Exercise 16.2 — Converting Stationary TPI GDP Back to Local Currency Units
--------------------------------------------------------------------------

This script loads three OG-Core test baseline files:

1. TPI_vars_baseline.pkl  – contains stationary transition-path variables (including Y_hat)
2. SS_vars_baseline.pkl   – contains the steady-state scaling factor "factor"
3. model_params_baseline.pkl – contains the parameters, including growth rates

OG-Core stationarizes aggregate variables using:

    Y_hat_t = Y_t / [ (1+g_y)^t * (1+g_n)^t * factor ]

To recover non-stationary GDP in local currency:

    Y_t = Y_hat_t * (1+g_y)^t * (1+g_n)^t * factor

Where:
 - g_y is the annual productivity growth rate
 - g_n is the steady-state population growth rate
 - factor is the scaling factor from the steady state

This script reconstructs Y_t and outputs a table containing:
 - stationary GDP
 - unstationarization growth factors
 - GDP in local currency units
"""

import pickle
import numpy as np
import requests
from io import BytesIO
import pandas as pd

# ---------------------------------------------------------
# Load baseline TPI variables
# ---------------------------------------------------------
url_tpi = "https://github.com/PSLmodels/OG-Core/raw/master/tests/test_io_data/TPI_vars_baseline.pkl"
tpi = pickle.load(BytesIO(requests.get(url_tpi).content))

# Load steady-state output (contains factor)
url_ss = "https://github.com/PSLmodels/OG-Core/raw/master/tests/test_io_data/SS_vars_baseline.pkl"
ss = pickle.load(BytesIO(requests.get(url_ss).content))

# Load parameters (Specifications object)
url_params = "https://github.com/PSLmodels/OG-Core/raw/master/tests/test_io_data/model_params_baseline.pkl"
params = pickle.load(BytesIO(requests.get(url_params).content))

# ---------------------------------------------------------
# Extract needed objects
# ---------------------------------------------------------
Y_stationary = tpi["Y"]      # stationary GDP series
factor_ss = ss["factor"]     # scaling factor from SS

# Growth rates
g_y = params.g_y_annual           # annual productivity growth
g_n = params.g_n_ss               # steady-state population growth

T = len(Y_stationary)

# ---------------------------------------------------------
# Undo OG-Core stationarization
# ---------------------------------------------------------

# Productivity growth term
G_prod = (1 + g_y) ** np.arange(T)

# Population growth term
G_pop = (1 + g_n) ** np.arange(T)

# Convert stationary → local currency GDP
Y_local = Y_stationary * G_pop * G_prod * factor_ss

# ---------------------------------------------------------
# Results table
# ---------------------------------------------------------
df = pd.DataFrame({
    "Y_stationary": Y_stationary,
    "G_pop": G_pop,
    "G_prod": G_prod,
    "Y_local_currency": Y_local
})

df.head(10)
# Out:
#    Y_stationary     G_pop    G_prod  Y_local_currency
# 0      0.429987  1.000000  1.000000      49697.890854
# 1      0.464691  1.001291  1.030000      55391.675141
# 2      0.486575  1.002583  1.060900      59817.406194
# 3      0.502667  1.003877  1.092727      63731.678256
# 4      0.515215  1.005173  1.125509      67369.079438
# 5      0.522506  1.006471  1.159274      70463.022306
# 6      0.531048  1.007770  1.194052      73858.668047
# 7      0.510047  1.009070  1.229874      73160.227228
# 8      0.514510  1.010373  1.266770      76112.543880
# 9      0.518197  1.011677  1.304773      79059.644378

# %% [markdown]
# Exercise 16.3 : Use the ogcore.output_tables.macro_table function to create a table that shows differences by year between macro variables in the baseline and reform model solutions.

# %%
"""
Exercise 16.3 — Macro Comparison Table: Baseline vs Reform (OG-Core)
--------------------------------------------------------------------

This script loads time-path (TPI) output and parameter files from two
OG-Core runs:

    • A baseline simulation
    • A reform simulation

Using these inputs, it applies the function:

    ogcore.output_tables.macro_table

to construct a table that compares key macroeconomic aggregates
between the baseline and reform paths on a year-by-year basis.

The table reports, for each variable in var_list:
    - Baseline level
    - Reform level
    - Absolute difference
    - Percentage difference

This is used to understand how the reform affects macro variables
over the transition path. The recommended variables include:
    Y  : Output
    C  : Consumption
    K  : Capital stock
    L  : Labor supply
    r  : Interest rate
    w  : Wage
"""

import pickle
import pandas as pd
from pathlib import Path
from ogcore.output_tables import macro_table

# --------------------------------------------------------
# Base directory where OG-Core results are stored
# --------------------------------------------------------
BASE = Path(r"C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OG-Core-Example")

# Baseline file paths
BASE_TPI = BASE / "OUTPUT_BASELINE" / "TPI" / "TPI_vars.pkl"
BASE_PARAMS = BASE / "OUTPUT_BASELINE" / "model_params.pkl"

# Reform file paths
REF_TPI = BASE / "OUTPUT_REFORM" / "TPI" / "TPI_vars.pkl"
REF_PARAMS = BASE / "OUTPUT_REFORM" / "model_params.pkl"

# --------------------------------------------------------
# Load BASELINE
# --------------------------------------------------------
with open(BASE_TPI, "rb") as f:
    TPI_baseline = pickle.load(f)

with open(BASE_PARAMS, "rb") as f:
    params_baseline = pickle.load(f)  # Specifications object

# --------------------------------------------------------
# Load REFORM
# --------------------------------------------------------
with open(REF_TPI, "rb") as f:
    TPI_reform = pickle.load(f)

with open(REF_PARAMS, "rb") as f:
    params_reform = pickle.load(f)

# --------------------------------------------------------
# Macro variables to include
# --------------------------------------------------------
macro_vars = ["Y", "C", "K", "L", "r", "w"]

# --------------------------------------------------------
# Create the macro comparison table
# --------------------------------------------------------
table = macro_table(
    TPI_baseline,
    params_baseline,
    TPI_reform,
    params_reform,
    var_list=macro_vars,
    output_type=None
)

table
# Out:
# Year                             Variable  2025  2026  2027  2028  2029  2030  \
# 0                    GDP ($Y_t$) Baseline  0.69  0.68  0.68  0.63  0.63  0.63
# 1                      GDP ($Y_t$) Reform  0.69  0.68  0.68  0.63  0.63  0.63
# 2            Consumption ($C_t$) Baseline  0.47  0.47  0.47  0.46  0.46  0.46
# 3              Consumption ($C_t$) Reform  0.47  0.47  0.47  0.46  0.46  0.45
# 4          Capital Stock ($K_t$) Baseline  2.16  2.16  2.16  2.14  2.11  2.08
# 5            Capital Stock ($K_t$) Reform  2.14  2.14  2.15  2.12  2.09  2.07
# 6                  Labor ($L_t$) Baseline  0.37  0.37  0.37  0.33  0.33  0.33
# 7                    Labor ($L_t$) Reform  0.37  0.37  0.37  0.33  0.33  0.33
# 8     Real interest rate ($r_t$) Baseline  0.06  0.06  0.06  0.05  0.05  0.05
# 9       Real interest rate ($r_t$) Reform  0.06  0.06  0.06  0.05  0.05  0.05
# 10           Wage rate ($w_{t}$) Baseline  1.20  1.21  1.21  1.25  1.24  1.24
# 11             Wage rate ($w_{t}$) Reform  1.20  1.20  1.20  1.25  1.24  1.24
#
# Year  2031  2032  2033  2034  2025-2034   SS
# 0     0.63  0.62  0.62  0.62       6.44 0.63
# 1     0.63  0.62  0.62  0.62       6.43 0.62
# 2     0.45  0.45  0.45  0.45       4.59 0.45
# 3     0.45  0.45  0.45  0.45       4.57 0.45
# 4     2.06  2.03  2.01  1.99      20.90 2.05
# 5     2.05  2.03  2.01  1.99      20.79 2.02
# 6     0.33  0.33  0.33  0.33       3.42 0.33
# 7     0.33  0.33  0.33  0.33       3.42 0.33
# 8     0.05  0.05  0.06  0.06       0.55 0.05
# 9     0.05  0.05  0.05  0.05       0.53 0.05
# 10    1.23  1.23  1.22  1.22      12.26 1.23
# 11    1.23  1.23  1.22  1.22      12.23 1.23

# %% [markdown]
# Exercies 16.4 : Use the ogcore.output_plots.plot_aggregates function to create a figure showing the percentage changes in GDP and consumption over the transition path between the baseline and reform simulations.

# %%
"""
Exercise 16.4 — Plot Percentage Changes in GDP and Consumption (OG-Core)
-----------------------------------------------------------------------

This script loads baseline and reform TPI (transition path) outputs and
their associated parameter objects. Using these inputs, it applies:

    ogcore.output_plots.plot_aggregates

to generate a figure that shows the **percentage differences over time**
between reform and baseline values for key macro aggregates.

The assignment requires plotting:
    - GDP (Y)
    - Aggregate Consumption (C)

The 'plot_type="pct_diff"' argument instructs OG-Core to compute:

    100 * (Reform_t - Baseline_t) / Baseline_t

for each year t of the transition path.

This figure illustrates how the reform affects output and consumption
relative to the baseline economy over time.
"""

import pickle
from pathlib import Path
from ogcore.output_plots import plot_aggregates

# --------------------------------------------------------
# Base directory where OG-Core results are stored
# --------------------------------------------------------
BASE = Path(r"C:\Users\Gyumin Kim\Desktop\Coursework\25-2R\Computational Methods for Economists\Problemset9\OG-Core-Example")

# Baseline file paths
BASE_TPI = BASE / "OUTPUT_BASELINE" / "TPI" / "TPI_vars.pkl"
BASE_PARAMS = BASE / "OUTPUT_BASELINE" / "model_params.pkl"

# Reform file paths
REF_TPI = BASE / "OUTPUT_REFORM" / "TPI" / "TPI_vars.pkl"
REF_PARAMS = BASE / "OUTPUT_REFORM" / "model_params.pkl"

# --------------------------------------------------------
# Load baseline run
# --------------------------------------------------------
with open(BASE_TPI, "rb") as f:
    TPI_baseline = pickle.load(f)

with open(BASE_PARAMS, "rb") as f:
    params_baseline = pickle.load(f)

# --------------------------------------------------------
# Load reform run
# --------------------------------------------------------
with open(REF_TPI, "rb") as f:
    TPI_reform = pickle.load(f)

with open(REF_PARAMS, "rb") as f:
    params_reform = pickle.load(f)

# --------------------------------------------------------
# Create % change plot of GDP and Consumption
# --------------------------------------------------------
fig = plot_aggregates(
    TPI_baseline,
    params_baseline,
    TPI_reform,
    params_reform,
    var_list=["Y", "C"],     # GDP and Consumption
    plot_type="pct_diff"     # Percent difference
)

# %% [markdown]
# Exercies 16.5 : Now use the ogcore.output_plots.plot_aggregates function to plot the baseline GDP forecast and the what that forecast (in levels) would look like under the reform scenario. This will involve setting the plot_type="forecast" and passing in an array that is the baseline GDP forecast (you can make this up or find a real forecast online - just note that the length of this array needs to be equal to the argument for num_years_to_plot , which defaults to 50 but can be adjusted).

# %%
"""
Exercise 16.5 — Baseline vs Reform GDP Forecast in Levels (OG-Core)
------------------------------------------------------------------

This script uses OG-Core's plot_aggregates function to compare how a
baseline GDP forecast would differ under the reform scenario.

Steps:
1. Load baseline and reform TPI variables and model parameters.
2. Construct a baseline GDP forecast in **levels**, using an assumed growth
   rate. (Here we use a simple 2% annual growth forecast, but any external
   forecast could be inserted.)
3. Call ogcore.output_plots.plot_aggregates with:
       - plot_type="forecast"
       - forecast_data=<GDP forecast array>
4. OG-Core then adjusts this forecast using the differences between
   the reform and baseline transition paths for GDP, producing a
   reform-adjusted forecast.

Important notes:
 - forecast_data must have the same length as num_years_to_plot.
 - var_list=["Y"] ensures that only GDP is plotted.
 - The forecast is in **levels**, not percent differences.
"""

import pickle
import numpy as np
import matplotlib.pyplot as plt
from ogcore.output_plots import plot_aggregates

# ---------------------------------------------------------
# Load baseline and reform TPI + parameter files
# ---------------------------------------------------------
with open("TPI_vars_baseline.pkl", "rb") as f:
    TPI_baseline = pickle.load(f)

with open("model_params_baseline.pkl", "rb") as f:
    params_baseline = pickle.load(f)

with open("TPI_vars_reform.pkl", "rb") as f:
    TPI_reform = pickle.load(f)

with open("model_params_reform.pkl", "rb") as f:
    params_reform = pickle.load(f)

# ---------------------------------------------------------
# Create a baseline GDP forecast (LEVELS)
# ---------------------------------------------------------
num_years = 50
initial_GDP = TPI_baseline["Y"][0]

# Example assumption: 2% annual GDP growth
g_forecast = 0.02

baseline_GDP_forecast = initial_GDP * (1 + g_forecast) ** np.arange(num_years)

# ---------------------------------------------------------
# Plot: Baseline GDP Forecast vs Reform-Adjusted Forecast
# ---------------------------------------------------------
fig = plot_aggregates(
    TPI_baseline,
    params_baseline,
    TPI_reform,
    params_reform,
    var_list=["Y"],                    # Only GDP
    plot_type="forecast",              # Required for Exercise 16.5
    forecast_data=baseline_GDP_forecast,
    forecast_units="Levels",
    num_years_to_plot=num_years
)

plt.show()

# %% [markdown]
# Exercies 17.1 : First, let’s gather population data from the UN Population Prospects for a country of interest to you. You can do this by calling the ogcore.demographics.get_un_data function. This function takes one positional argument, the UN variable code, and three keyword arguments, the country code, the start year, and the end year. The UN variable code is a string that identifies the data you want to pull from the UN database. The country code is a string that identifies the country you want to pull data for. The start year and end year are integers that identify the range of years you want to pull data for. The function returns a pandas DataFrame with the data you requested. Use this function to pull data for a country of interest to you. You can find the UN variable codes and country codes in the UN Population Prospects documentation. Because the UN has an API token for data access, please select a variable code from “68” (fertility rates), “80” (mortality rates), or “47” (population by age) for this exercise. Also choose a country code from the following list: “840” (United States), “710” (South Africa), “458” (Malaysia), “356” India, “826” (United Kingdom), “360” (Indonesia), “608” (Philippines). Note that the maximum year value is 2100. Also note that retrieving data will require an internet connection you will be prompted for an API token, but if you don’t have one, just hit enter and the function will still work.

# %%
"""
Exercise 17.1 — Retrieving UN Population Prospects Data Using OG-Core
---------------------------------------------------------------------

This exercise demonstrates how to download demographic data from the
United Nations World Population Prospects (WPP) using the OG-Core
function:

    ogcore.demographics.get_un_data

The function retrieves demographic series for a chosen country and
variable (e.g., fertility, mortality, or population by age).

Inputs:
- variable_code : UN WPP code for the dataset to retrieve.
        "68" = Fertility rates
        "80" = Mortality rates
        "47" = Population by age (used in this example)

- country_id : UN numeric country code (string)
        Examples allowed for this exercise:
        "840" = USA
        "826" = United Kingdom
        "710" = South Africa
        "360" = Indonesia
        "458" = Malaysia
        "608" = Philippines
        "356" = India

- start_year, end_year : Range of years (must not exceed 2100)

The function returns a pandas DataFrame containing the requested UN data.
If an API token is requested, pressing ENTER will still allow the data
to be fetched for these variables.

Here we retrieve population-by-age data for the United Kingdom from
2020 to 2100.
"""

from ogcore.demographics import get_un_data

# -------------------------------------------
# Exercise 17.1: Population data for UK
# -------------------------------------------

variable_code = "47"        # Population by age
country_id    = "826"       # United Kingdom
start_year    = 2020
end_year      = 2050

# Retrieve UN demographic data
uk_pop = get_un_data(
    variable_code,
    country_id=country_id,
    start_year=start_year,
    end_year=end_year
)

# Display first rows
uk_pop.head()
# Out:
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
#    year  age     value
# 0  2020    0  709605.0
# 1  2020    1  738935.0
# 2  2020    2  767944.0
# 3  2020    3  793290.5
# 4  2020    4  812404.5

# %% [markdown]
# Exercies 17.2 : Using your modified demographics.py, plot the fertility rates in this country. Note that you can do this directly from the demographics.get_fert() function.

# %%
"""
Exercise 17.2 — Plot Fertility Rates Using demographics.get_fert()
------------------------------------------------------------------

We first retrieve raw UN fertility data (variable 68) to determine the
actual age grid (the UN WPP dataset often uses 5-year age groups,
e.g. ages 15,20,25,...,45). We then call get_fert() with matching
min_age, max_age, and totpers so that pop_rebin() does not crash.

This is the intended workflow in the reading: use your modified
demographics.py together with get_fert().
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ogcore.demographics import get_un_data, get_fert

# -------------------------------------------
# Step 1: Get raw fertility data (UN variable 68)
# -------------------------------------------
country_id = "826"   # UK
start_year = 2020
end_year   = 2050

fert_raw = get_un_data(
    "68",
    country_id=country_id,
    start_year=start_year,
    end_year=end_year
)

print("Raw fertility data:")
print(fert_raw.head())

# -------------------------------------------
# Step 2: Determine correct fertility age bins
# -------------------------------------------
ages = sorted(fert_raw["age"].unique())
min_age = min(ages)
max_age = max(ages)
totpers = len(ages)

print("min_age:", min_age)
print("max_age:", max_age)
print("totpers:", totpers)

# -------------------------------------------
# Step 3: Call get_fert() using correct age grid
# -------------------------------------------
fert_rates = get_fert(
    totpers=totpers,
    min_age=min_age,
    max_age=max_age,
    country_id=country_id,
    start_year=start_year,
    end_year=end_year,
    graph=False
)

# fert_rates shape = (#years , #age bins)
years = list(range(start_year, end_year+1))

fert_df = pd.DataFrame(fert_rates, index=years, columns=ages)

# -------------------------------------------
# Plot fertility for first and last year
# -------------------------------------------
fert_first = fert_df.loc[start_year]
fert_last  = fert_df.loc[end_year]

plt.figure(figsize=(10,6))
plt.plot(ages, fert_first, label=str(start_year))
plt.plot(ages, fert_last,  label=str(end_year))

plt.title(f"UK Fertility Rates by Age (using get_fert)")
plt.xlabel("Age of Mother")
plt.ylabel("Fertility Rate (births per woman)")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Raw fertility data:
#    year  age   value
# 0  2020   15   0.857
# 1  2020   16   2.726
# 2  2020   17   7.466
# 3  2020   18  13.910
# 4  2020   19  23.849
# min_age: 15
# max_age: 49
# totpers: 35
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API

# %% [markdown]
# Exercise 17.3 : Let’s do the same for mortality rates. In this case, you will want interact with the demographics.get_mort function.

# %%
"""
Exercise 17.3 — Plot Mortality Rates Using demographics.get_mort()
------------------------------------------------------------------

We follow the same method as Exercise 17.2:

1. Retrieve raw UN mortality data using get_un_data("80").
2. Determine the correct age bins from the UN data (min_age, max_age, totpers).
3. Call get_mort() with these correct parameters.
4. Plot mortality curves for the first and last available years.

This guarantees compatibility, avoids empty rows, and uses the official
mortality function in demographics.py as required.
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ogcore.demographics import get_un_data, get_mort

# -------------------------------------------
# Step 1: Retrieve raw mortality data for the UK
# -------------------------------------------
country_id = "826"     # United Kingdom
start_year = 2020
end_year   = 2050

mort_raw = get_un_data(
    "80",                      # mortality variable
    country_id=country_id,
    start_year=start_year,
    end_year=end_year
)

print("Raw mortality data:")
print(mort_raw.head())

# -------------------------------------------
# Step 2: Determine mortality age bins
# -------------------------------------------
ages = sorted(mort_raw["age"].unique())
min_age = min(ages)
max_age = max(ages)
totpers = len(ages)

print("min_age:", min_age)
print("max_age:", max_age)
print("totpers:", totpers)

# -------------------------------------------
# Step 3: Call get_mort() with correct age grid
# -------------------------------------------
mort_rates, infmort_rates = get_mort(
    totpers=totpers,
    min_age=min_age,
    max_age=max_age,
    country_id=country_id,
    start_year=start_year,
    end_year=end_year,
    graph=False
)

# Convert to DataFrame for convenience
years = list(range(start_year, end_year + 1))
mort_df = pd.DataFrame(mort_rates, index=years, columns=ages)

# -------------------------------------------
# Step 4: Plot first and last year mortality
# -------------------------------------------
mort_first = mort_df.loc[start_year]
mort_last  = mort_df.loc[end_year]

plt.figure(figsize=(10,6))
plt.plot(ages, mort_first, label=str(start_year))
plt.plot(ages, mort_last,  label=str(end_year))

plt.title("UK Age-Specific Mortality Rates (using get_mort)")
plt.xlabel("Age")
plt.ylabel("Mortality Rate")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Raw mortality data:
#    year  age     value
# 0  2020    0  0.003704
# 1  2020    1  0.000181
# 2  2020    2  0.000120
# 3  2020    3  0.000101
# 4  2020    4  0.000075
# min_age: 0
# max_age: 99
# totpers: 100
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API

# %% [markdown]
# Exercise 17.4: The demographics.py module uses current fertility and mortality rates (and the implied immigration rates) to project the population forward. This ensures a population distribution in each year of the model that is consistent with the fertility, mortality, and immigration rates. Use the demographics.get_pop_objs function to return a dictionary with the population object that are inputs to calibrating OG-Core (Use E=20 , S=80 , T=320 , curr_year=2023 ). From this dictionary, extract the population distribution object (the key for this is omega and it is an array with shape TxS , where T are the number of time periods and S is the number of age groups in the model). Create a line plot of the population distribution in the first year, the 20th year, the 100th year, and the last year in the omega object. Describe what you see
# happening to the distribution of people across age as you more forward in time?

# %%
import numpy as np
import matplotlib.pyplot as plt
from ogcore.demographics import get_pop_objs

# ---------------------------
# Model settings
# ---------------------------
E = 20
S = 80
T = 320

# ---------------------------
# Retrieve population objects
# ---------------------------
pop_dict = get_pop_objs(E=E, S=S, T=T)

# omega has shape (T, S)
omega = pop_dict["omega"]
print("omega shape:", omega.shape)

# ---------------------------
# Select years to plot
# ---------------------------
years_to_plot = [0, 19, 99, 319]
labels = ["Year 1", "Year 20", "Year 100", "Year 320"]

ages = np.arange(1, S + 1)

# ---------------------------
# Plot population distributions
# ---------------------------
plt.figure(figsize=(10, 6))

for t, label in zip(years_to_plot, labels):
    plt.plot(ages, omega[t, :], label=label)

plt.xlabel("Age")
plt.ylabel("Population Share")
plt.title("Population Distribution Across Ages Over Time")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Demographics data: Initial Data year =  2023 , Final Data year =  2026
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Pre-period population verification: Max diff =  46483.600326016545
# POP. SUCCESS: orig. SS pop. dist is very close to period-T pop. dist'n. The maximum absolute difference is 2.1061922522488258e-06.
# POP. SUCCESS: The maximum absolute difference between any two corresponding points in the original and adjusted steady-state population distributions is 0.00015236704336155787
# POP. SUCCESS: Adjusted immigration rates solved with maximum absolute error of 0.0, which is less than the tolerance of 1e-14
# SUCCESS: The steady-state population growth rate from adjusted OMEGA is close to (diff is 0.0) the steady-state population growth rate from the original OMEGA.
# The maximum absolute difference between the adjusted steady-state population distribution and the distribution generated by hitting the adjusted OMEGA transition matrix is 1.6757883318802708e-05
# The maximum absolute distance between any two points of the original immigration rates and adjusted immigration rates is 0.007611715911741181
# omega shape: (400, 80)

# %% [markdown]
# Answers 17.4 : (1) Describe what you see happening to the distribution of people across age as you more forward in time?
#
# As time moves forward, the population distribution shifts toward older ages. In the early years, the population is younger and more uneven across ages. By Year 20 and Year 100, the share of middle-aged and older individuals increases, and the distribution smooths out. By Year 320, the age distribution has converged to its steady-state form—stable, smoother, and more heavily weighted toward older ages compared to Year 1. Overall, the population is aging and eventually reaches a long-run demographic steady state.

# %% [markdown]
# Exercies 17.5 : Also in the dictionary returned from demographics.get_pop_objs , is the population growth rate. This is a NumPy array object with key g_n . Plot g_n . How does the population growth rate change over time? Given what you’ve seen in the plots you’ve created, what can you say about the driver(s) of population growth (i.e., how are fertility and mortality rates contributing? What about immigration (something we
# haven’t yet plotted, but about which you might be able to infer something given fertility and mortality rates and the change in the age distribution over time…))

# %%
import numpy as np
import matplotlib.pyplot as plt
from ogcore.demographics import get_pop_objs

# --------------------------
# OG-Core demographic settings
# --------------------------
E = 20     # childhood periods
S = 80     # adult periods
T = 320    # projection years

# Retrieve demographic objects
pop_dict = get_pop_objs(E=E, S=S, T=T)

# Extract population growth rates
g_n = pop_dict["g_n"]       # shape (T,)
print("Shape of g_n:", g_n.shape)

# --------------------------
# Plot g_n(t)
# --------------------------
plt.figure(figsize=(10,5))
plt.plot(g_n, label="Population Growth Rate g_n(t)")
plt.axhline(0, color='k', linewidth=0.8)
plt.xlabel("Model Period t")
plt.ylabel("Population Growth Rate")
plt.title("Population Growth Rate Over Time")
plt.grid(True)
plt.legend()
plt.show()

# Summary statistics
print("First 5 g_n values: ", np.round(g_n[:5], 4))
print("Last 5 g_n values:  ", np.round(g_n[-5:], 4))
print("Mean g_n (first 50):", g_n[:50].mean())
print("Mean g_n (last 50): ", g_n[-50:].mean())
# Out:
# Demographics data: Initial Data year =  2023 , Final Data year =  2026
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Failed to retrieve population data from UN. Reading  from https://github.com/EAPD-DRB/Population-Data instead of UN WPP API
# Pre-period population verification: Max diff =  46483.600326016545
# POP. SUCCESS: orig. SS pop. dist is very close to period-T pop. dist'n. The maximum absolute difference is 2.1061922522488258e-06.
# POP. SUCCESS: The maximum absolute difference between any two corresponding points in the original and adjusted steady-state population distributions is 0.00015236704336155787
# POP. SUCCESS: Adjusted immigration rates solved with maximum absolute error of 0.0, which is less than the tolerance of 1e-14
# SUCCESS: The steady-state population growth rate from adjusted OMEGA is close to (diff is 0.0) the steady-state population growth rate from the original OMEGA.
# The maximum absolute difference between the adjusted steady-state population distribution and the distribution generated by hitting the adjusted OMEGA transition matrix is 1.6757883318802708e-05
# The maximum absolute distance between any two points of the original immigration rates and adjusted immigration rates is 0.007611715911741181
# Shape of g_n: (400,)
# First 5 g_n values:  [0.0093 0.0091 0.0086 0.0086 0.0087]
# Last 5 g_n values:   [-0.0013 -0.0013 -0.0013 -0.0013 -0.0013]
# Mean g_n (first 50): 0.0024840838994860297
# Mean g_n (last 50):  -0.0013250406917106883

# %% [markdown]
# A: Interpretation :
#
# (1) How does the population growth rate change over time?
# The population growth rate starts out positive but falls quickly and becomes negative within the first 50 periods. It then converges to a small negative steady-state rate.
#
# (2) Given what you’ve seen in the plots you’ve created, what can you say about the driver(s) of population growth (i.e., how are fertility and mortality rates contributing? What about immigration (something we haven’t yet plotted, but about which you might be able to infer something given fertility and mortality rates and the change in the age distribution over time…))
#
# This decline is primarily driven by falling fertility rates, which reduce the inflow of new young cohorts into the population. Mortality improvements increase longevity but mainly shift the age distribution toward older ages rather than increasing population growth. We can also infer that immigration plays a stabilizing role, but its level is not high enough to counteract low fertility. Overall, fertility decline is the dominant driver of the falling population growth rate, while mortality and immigration shape the age distribution but do not reverse the long-run negative growth trend.

# %% [markdown]
# Exercise 17.6: Now that you’ve visualized the different demographic trends in the country you’ve chosen, let’s see how these affect the equilibrium in the OG model. This will combine what you learned in Simulating OG-Core with what you’ve learned here about population demographics objects for the model. You’ll proceed with the following steps:

# %%
"""
Exercise 17.6 — Effect of Alternative Demographics on OG-Core Steady State
--------------------------------------------------------------------------

This exercise:
 1. Runs a baseline OG-Core steady state using default demographics.
 2. Constructs new population objects (omega, g_n, mortality, fertility, immigration)
    using get_pop_objs().
 3. Inserts these demographics into a reform Specifications object.
 4. Solves the new steady state.
 5. Compares baseline vs reform steady-state macro variables using macro_table_SS.
"""

import os
from pathlib import Path
import pickle
from ogcore.parameters import Specifications
from ogcore.execute import runner
from ogcore.demographics import get_pop_objs
from ogcore.output_tables import macro_table_SS

# ---------------------------------------------------------
# 1) Create output directories for baseline and reform runs
# ---------------------------------------------------------
BASE_DIR = Path("OGCORE_OUTPUT_BASELINE")
REFORM_DIR = Path("OGCORE_OUTPUT_REFORM")

BASE_DIR.mkdir(parents=True, exist_ok=True)
REFORM_DIR.mkdir(parents=True, exist_ok=True)

# ---------------------------------------------------------
# 2) Baseline steady-state simulation
# ---------------------------------------------------------
p_base = Specifications(
    baseline=True,
    baseline_dir=str(BASE_DIR),
    output_base=str(BASE_DIR),
)

print("Running BASELINE steady state...")
runner(p_base)
print("Baseline completed.")

# ---------------------------------------------------------
# 3) Construct population objects with updated demographics
# ---------------------------------------------------------
E = 20
S = 80
T = 320
curr_year = 2023   # as in exercise prompt

pop_objs = get_pop_objs(E=E, S=S, T=T, initial_data_year=curr_year)

# ---------------------------------------------------------
# 4) Reform steady-state simulation using updated demographics
# ---------------------------------------------------------
p_reform = Specifications(
    baseline=False,
    baseline_dir=str(BASE_DIR),
    output_base=str(REFORM_DIR),
)

# Insert population objects into reform specifications
p_reform.update_specifications(pop_objs)

print("Running REFORM steady state with updated demographics...")
runner(p_reform)
print("Reform completed.")

# ---------------------------------------------------------
# 5) Load steady-state outputs
# ---------------------------------------------------------
def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

ss_base = load_pkl(BASE_DIR / "SS/SS_vars.pkl")
params_base = load_pkl(BASE_DIR / "model_params.pkl")

ss_reform = load_pkl(REFORM_DIR / "SS/SS_vars.pkl")
params_reform = load_pkl(REFORM_DIR / "model_params.pkl")

# ---------------------------------------------------------
# 6) Compare steady-state macro outcomes
# ---------------------------------------------------------
table_ss = macro_table_SS(
    ss_base,
    params_base,
    ss_reform,
    params_reform,
    output_type=None
)

print("\n=== STEADY STATE COMPARISON TABLE ===")
print(table_ss)
# Out:
# SS using initial guess factors for r and TR of 1.0 and 1.0 respectively.
# Running baseline steady state. This may take a while...
# making dir:  /path/to/OUTPUT_BASELINE\SS
# making dir:  /path/to/OUTPUT_BASELINE\TPI
# In runner, baseline is  True
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '-1.490e-08', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['2.977e-03', '1.150e-02', '-5.894e-02', '0.000e+00', '-4.347e-03', '1.324e-02', '1.829e-02', '1.984e-02', '1.212e-02', '1.443e-02', '1.749e-02', '3.488e-03', '-3.912e-04', '-3.462e-02']
# GE loop errors = ['-7.776e-02', '-8.853e-02', '1.057e+00', '-2.220e-16', '1.158e-02', '-8.707e-04', '-6.208e-01', '6.336e-01', '-2.623e-01', '9.476e-01', '-5.198e-01', '7.732e-02', '1.042e-03', '6.444e-02']
# GE loop errors = ['-1.213e-01', '-1.325e-01', '2.196e+00', '-2.085e-03', '-1.567e-01', '4.654e-03', '1.997e-01', '-1.175e-01', '1.636e-01', '-2.364e-01', '3.285e-01', '-1.736e-02', '-1.410e-02', '5.672e-01']
# GE loop errors = ['-8.769e-02', '-9.082e-02', '1.593e+00', '0.000e+00', '-1.920e-01', '1.209e-02', '3.374e-02', '6.088e-02', '5.655e-02', '2.576e-02', '1.071e-01', '8.579e-03', '-1.728e-02', '3.747e-01']
# GE loop errors = ['-8.696e-02', '-9.008e-02', '1.546e+00', '0.000e+00', '-2.260e-01', '1.210e-02', '3.036e-02', '5.480e-02', '5.092e-02', '2.319e-02', '9.643e-02', '7.726e-03', '-2.034e-02', '3.770e-01']
# GE loop errors = ['-8.615e-02', '-8.926e-02', '1.497e+00', '0.000e+00', '-2.569e-01', '1.211e-02', '2.731e-02', '4.934e-02', '4.585e-02', '2.087e-02', '8.685e-02', '6.958e-03', '-2.312e-02', '3.798e-01']
# GE loop errors = ['-8.527e-02', '-8.836e-02', '1.446e+00', '-1.490e-08', '-2.848e-01', '1.212e-02', '2.457e-02', '4.442e-02', '4.129e-02', '1.879e-02', '7.822e-02', '6.266e-03', '-2.563e-02', '3.832e-01']
# GE loop errors = ['-8.430e-02', '-8.736e-02', '1.392e+00', '0.000e+00', '-3.102e-01', '1.213e-02', '2.211e-02', '3.999e-02', '3.719e-02', '1.691e-02', '7.046e-02', '5.644e-03', '-2.792e-02', '3.870e-01']
# GE loop errors = ['-8.324e-02', '-8.625e-02', '1.337e+00', '0.000e+00', '-3.334e-01', '1.214e-02', '1.989e-02', '3.601e-02', '3.349e-02', '1.523e-02', '6.347e-02', '5.084e-03', '-3.001e-02', '3.914e-01']
# GE loop errors = ['-8.207e-02', '-8.502e-02', '1.279e+00', '0.000e+00', '-3.545e-01', '1.216e-02', '1.789e-02', '3.242e-02', '3.017e-02', '1.371e-02', '5.718e-02', '4.580e-03', '-3.190e-02', '3.962e-01']
# GE loop errors = ['-8.080e-02', '-8.366e-02', '1.218e+00', '0.000e+00', '-3.738e-01', '1.217e-02', '1.609e-02', '2.919e-02', '2.717e-02', '1.234e-02', '5.152e-02', '4.126e-03', '-3.364e-02', '4.015e-01']
# GE loop errors = ['-7.940e-02', '-8.214e-02', '1.156e+00', '0.000e+00', '-3.914e-01', '1.219e-02', '1.447e-02', '2.629e-02', '2.448e-02', '1.111e-02', '4.642e-02', '3.717e-03', '-3.523e-02', '4.073e-01']
# GE loop errors = ['-7.787e-02', '-8.045e-02', '1.092e+00', '0.000e+00', '-4.076e-01', '1.221e-02', '1.301e-02', '2.367e-02', '2.205e-02', '1.000e-02', '4.183e-02', '3.350e-03', '-3.669e-02', '4.135e-01']
# GE loop errors = ['-7.618e-02', '-7.856e-02', '1.026e+00', '0.000e+00', '-4.225e-01', '1.223e-02', '1.170e-02', '2.131e-02', '1.987e-02', '9.006e-03', '3.770e-02', '3.019e-03', '-3.803e-02', '4.202e-01']
# GE loop errors = ['-7.433e-02', '-7.645e-02', '9.583e-01', '0.000e+00', '-4.363e-01', '1.226e-02', '1.052e-02', '1.919e-02', '1.790e-02', '8.108e-03', '3.398e-02', '2.721e-03', '-3.927e-02', '4.272e-01']
# GE loop errors = ['-7.230e-02', '-7.407e-02', '8.889e-01', '0.000e+00', '-4.491e-01', '1.228e-02', '9.456e-03', '1.729e-02', '1.613e-02', '7.300e-03', '3.064e-02', '2.452e-03', '-4.041e-02', '4.347e-01']
# GE loop errors = ['-7.006e-02', '-7.139e-02', '8.179e-01', '0.000e+00', '-4.609e-01', '1.231e-02', '8.499e-03', '1.557e-02', '1.454e-02', '6.572e-03', '2.763e-02', '2.211e-03', '-4.148e-02', '4.425e-01']
# GE loop errors = ['-4.441e-02', '-1.634e-01', '1.990e+00', '-1.080e-11', '-2.389e-01', '9.864e-03', '7.901e-03', '1.410e-02', '1.303e-02', '6.008e-03', '2.461e-02', '1.986e-03', '-2.150e-02', '4.948e-01']
# GE loop errors = ['-4.916e-02', '-1.340e-01', '1.842e+00', '-3.221e-11', '-4.677e-01', '9.471e-03', '7.005e-03', '1.267e-02', '1.176e-02', '5.391e-03', '2.229e-02', '1.798e-03', '-4.209e-02', '5.657e-01']
# GE loop errors = ['-4.801e-02', '-9.140e-02', '1.156e+00', '-3.694e-11', '-5.073e-01', '6.782e-03', '6.271e-03', '1.146e-02', '1.069e-02', '4.859e-03', '2.029e-02', '1.632e-03', '-4.566e-02', '4.676e-01']
# GE loop errors = ['-5.364e-02', '-6.827e-02', '6.912e-01', '-3.582e-11', '-4.789e-01', '1.046e-02', '5.582e-03', '1.028e-02', '9.615e-03', '4.342e-03', '1.829e-02', '1.465e-03', '-4.310e-02', '4.696e-01']
# GE loop errors = ['-5.262e-02', '-5.628e-02', '5.097e-01', '-4.008e-11', '-4.955e-01', '1.163e-02', '4.992e-03', '9.247e-03', '8.670e-03', '3.900e-03', '1.651e-02', '1.321e-03', '-4.459e-02', '4.811e-01']
# GE loop errors = ['-4.924e-02', '-4.704e-02', '3.901e-01', '-4.163e-11', '-5.109e-01', '1.214e-02', '4.474e-03', '8.329e-03', '7.825e-03', '3.509e-03', '1.492e-02', '1.193e-03', '-4.598e-02', '4.890e-01']
# GE loop errors = ['-4.239e-02', '-3.790e-02', '2.880e-01', '-4.236e-11', '-5.230e-01', '1.244e-02', '4.022e-03', '7.525e-03', '7.081e-03', '3.168e-03', '1.351e-02', '1.080e-03', '-4.707e-02', '4.773e-01']
# GE loop errors = ['-3.352e-02', '-2.761e-02', '1.915e-01', '-4.270e-11', '-5.330e-01', '1.266e-02', '3.621e-03', '6.809e-03', '6.418e-03', '2.864e-03', '1.226e-02', '9.795e-04', '-4.797e-02', '4.600e-01']
# SS using initial guess factors for r and TR of 0.95 and 1.0 respectively.
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '-1.490e-08', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['8.095e-03', '1.669e-02', '-8.642e-02', '0.000e+00', '-7.806e-03', '1.294e-02', '1.792e-02', '1.948e-02', '1.192e-02', '1.420e-02', '1.715e-02', '3.404e-03', '-7.025e-04', '-3.449e-02']
# GE loop errors = ['-9.275e-03', '-9.646e-03', '4.485e-02', '0.000e+00', '-2.508e-02', '3.601e-02', '3.617e-02', '3.619e-02', '1.831e-02', '1.107e-03', '7.557e-02', '4.605e-03', '-2.257e-03', '5.732e-03']
# GE loop errors = ['-7.891e-04', '4.148e-03', '-1.511e-02', '-3.304e-03', '6.562e-03', '1.687e-02', '1.968e-02', '2.072e-02', '9.424e-03', '3.704e-03', '3.164e-02', '-3.428e-04', '5.906e-04', '-1.645e-02']
# GE loop errors = ['-8.341e-04', '-8.789e-04', '6.386e-03', '0.000e+00', '-3.810e-03', '9.368e-03', '9.379e-03', '9.290e-03', '4.714e-03', '7.052e-05', '1.906e-02', '1.117e-03', '-3.429e-04', '9.652e-04']
# GE loop errors = ['1.084e-04', '1.131e-04', '-4.893e-04', '0.000e+00', '-2.365e-04', '5.476e-03', '5.467e-03', '5.530e-03', '2.710e-03', '-4.892e-05', '1.113e-02', '7.110e-04', '-2.128e-05', '3.138e-05']
# GE loop errors = ['2.961e-04', '3.031e-04', '-2.917e-04', '0.000e+00', '7.375e-04', '-1.965e-04', '-1.843e-04', '-2.036e-04', '-8.413e-05', '3.720e-05', '-3.947e-04', '-1.912e-05', '6.637e-05', '-5.759e-05']
# GE loop errors = ['2.162e-05', '2.186e-05', '3.510e-05', '0.000e+00', '-3.993e-05', '9.701e-05', '9.680e-05', '9.620e-05', '4.851e-05', '-1.164e-06', '1.928e-04', '1.116e-05', '-3.593e-06', '9.077e-06']
# GE loop errors = ['8.407e-06', '8.551e-06', '3.198e-06', '0.000e+00', '-6.216e-06', '2.687e-05', '2.689e-05', '2.690e-05', '1.352e-05', '1.303e-08', '5.377e-05', '3.143e-06', '-5.595e-07', '1.433e-06']
# GE loop errors = ['2.950e-07', '2.993e-07', '2.758e-07', '0.000e+00', '-5.907e-08', '3.486e-07', '3.503e-07', '3.315e-07', '1.789e-07', '2.851e-09', '6.889e-07', '3.830e-08', '-5.316e-09', '6.088e-08']
# GE loop errors = ['1.981e-08', '2.018e-08', '2.422e-10', '0.000e+00', '-2.442e-08', '7.272e-08', '7.279e-08', '7.386e-08', '3.659e-08', '3.946e-10', '1.464e-07', '8.629e-09', '-2.198e-09', '2.250e-09']
# GE loop errors = ['-6.032e-09', '-6.146e-09', '1.588e-10', '0.000e+00', '7.300e-09', '-2.312e-08', '-2.314e-08', '-2.349e-08', '-1.163e-08', '-1.139e-10', '-4.654e-08', '-2.749e-09', '6.570e-10', '-6.672e-10']
# GE loop errors = ['2.004e-11', '2.039e-11', '6.033e-12', '0.000e+00', '-3.192e-11', '4.741e-11', '4.750e-11', '4.840e-11', '2.401e-11', '6.549e-13', '9.593e-11', '5.526e-12', '-2.873e-12', '2.663e-12']
# GE loop errors = ['7.674e-13', '7.807e-13', '2.609e-13', '0.000e+00', '-1.249e-12', '1.562e-12', '1.566e-12', '1.597e-12', '7.933e-13', '2.793e-14', '3.168e-12', '1.814e-13', '-1.124e-13', '1.009e-13']
# Iteration: 1  Distance: 1.0391492421634068e-10
# SS debt = 1.2067673185280094, 0.015342656492163374
# IO: (1, 1), C: (1,)
# Foreign debt holdings = 0.4827069274112038
# Foreign capital holdings = 0.08516430154921899
# resource constraint: [-1.64278313e-13]
# Steady state government spending is negative to satisfy budget
# Checking constraints on capital, labor, and consumption.
# There were no violations of the constraints on labor supply.
# There were no violations of the constraints on consumption.
# Maximum error in labor FOC = 1.474376176702208e-13
# Maximum error in savings FOC = 1.0125233984581428e-13
# c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\SS.py:1568: UserWarning: Warning: The combination of the tax policy you specified and your target debt-to-GDP ratio results in an infeasible amount of government spending in order to close the budget (i.e., G < 0)
#   warnings.warn(
# JUST SAVED SS output to  /path/to/OUTPUT_BASELINE\SS\SS_vars.pkl
# Government spending breakpoints are tG1: 20; and tG2: 256
# w diff: 0.030295730009631372, -0.025983841729739776
# r diff: 0.004879122175608222, -0.005338357829043711
# r_p diff: 0.007006420270724484, -0.003500120927726183
# p_m diff: 0.0, 0.0
# BQ diff: 0.003002716866421829, -2.05306564653486e-05
# TR diff: 0.004119441357007925, -2.071209908682814e-05
# Iteration: 1
# Distance: 0.16512680441884783
# Maximum debt ratio:  2.0004196390597135
# w diff: 0.057741106814498844, -0.0012143563783937328
# r diff: 0.00020103560187439973, -0.009280224158756428
# r_p diff: 0.0001957837606685331, -0.008035921280484644
# p_m diff: 0.0, 0.0
# BQ diff: 0.0019276573475300145, -6.0208068011873006e-05
# TR diff: 0.004448761211196306, -4.841618588109775e-06
# Iteration: 2
# Distance: 0.16126562311192724
# Maximum debt ratio:  2.0004515146261084
# w diff: 0.027349611378317373, 6.727036765519223e-05
# r diff: -1.189528803323403e-05, -0.004515685654275917
# r_p diff: -1.1147621430035448e-05, -0.0038283605773601417
# p_m diff: 0.0, 0.0
# BQ diff: 0.0011221525278667793, -3.373832965656784e-05
# TR diff: 0.0024078515383361074, -2.5206223915053005e-06
# Iteration: 3
# Distance: 0.08280230965147328
# Maximum debt ratio:  2.000302881281126
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[96], line 33
#      31 print("Running baseline steady state. This may take a while...")
#      32 try:
# ---> 33     runner(p)   # runs baseline SS and writes outputs under BASE_DIR
#      34 except Exception as e:
#      35     print("Error running baseline runner():", e)
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\execute.py:69, in runner(p, time_path, client)
#      63 if time_path:
#      64     """
#      65     ------------------------------------------------------------------------
#      66         Run the TPI simulation
#      67     ------------------------------------------------------------------------
#      68     """
# ---> 69     tpi_output = TPI.run_TPI(p, client=client)
#      71     """
#      72     ------------------------------------------------------------------------
#      73         Pickle TPI results
#      74     ------------------------------------------------------------------------
#      75     """
#      76     tpi_dir = os.path.join(p.output_base, "TPI")
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\TPI.py:816, in run_TPI(p, client)
#     814     for j in range(p.J):
#     815         guesses = (guesses_b[:, :, j], guesses_n[:, :, j])
# --> 816         res = inner_loop(
#     817             guesses,
#     818             outer_loop_vars,
#     819             initial_values,
#     820             ubi,
#     821             j,
#     822             ind,
#     823             p,  # pass the raw object directly
#     824         )
#     825         results.append(res)
#     826 for j, result in enumerate(results):
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\TPI.py:514, in inner_loop(guesses, outer_loop_vars, initial_values, ubi, j, ind, p)
#     505 mtrx_params_to_use = [
#     506     [p.mtrx_params[t + s][s][i] for i in range(num_params)]
#     507     for s in range(p.S)
#     508 ]
#     509 mtry_params_to_use = [
#     510     [p.mtry_params[t + s][s][i] for i in range(num_params)]
#     511     for s in range(p.S)
#     512 ]
# --> 514 solutions = opt.root(
#     515     twist_doughnut,
#     516     list(b_guesses_to_use) + list(n_guesses_to_use),
#     517     args=(
#     518         r_p,
#     519         w,
#     520         p_tilde,
#     521         bq_to_use,
#     522         rm_to_use,
#     523         tr_to_use,
#     524         theta_to_use,
#     525         factor,
#     526         ubi_to_use,
#     527         j,
#     528         None,
#     529         t,
#     530         etr_params_to_use,
#     531         mtrx_params_to_use,
#     532         mtry_params_to_use,
#     533         initial_b,
#     534         p,
#     535     ),
#     536     method=p.FOC_root_method,
#     537     tol=MINIMIZER_TOL,
#     538 )
#     539 euler_errors[t, :] = solutions.fun
#     541 b_vec = solutions.x[: p.S]
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\scipy\optimize\_root.py:253, in root(fun, x0, args, method, jac, tol, callback, options)
#     250         options.setdefault('fatol', np.inf)
#     252 if meth == 'hybr':
# --> 253     sol = _root_hybr(_wrapped_fun, x0, args=args, jac=jac, **options)
#     254 elif meth == 'lm':
#     255     sol = _root_leastsq(_wrapped_fun, x0, args=args, jac=jac, **options)
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\scipy\optimize\_minpack_py.py:249, in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     247     if maxfev == 0:
#     248         maxfev = 200 * (n + 1)
# --> 249     retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
#     250                              ml, mu, epsfcn, factor, diag)
#     251 else:
#     252     _check_func('fsolve', 'fprime', Dfun, x0, args, n, (n, n))
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\scipy\optimize\_root.py:215, in root.<locals>._wrapped_fun(*fargs)
#     210 """
#     211 Wrapped `func` to track the number of times
#     212 the function has been called.
#     213 """
#     214 _wrapped_fun.nfev += 1
# --> 215 return fun(*fargs)
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\TPI.py:310, in twist_doughnut(guesses, r, w, p_tilde, bq, rm, tr, theta, factor, ubi, j, s, t, etr_params, mtrx_params, mtry_params, initial_b, p)
#     286 rho_s = np.diag(p.rho[t : t + p.S, :], max(p.S - length, 0))
#     288 error1 = household.FOC_savings(
#     289     r_s,
#     290     w_s,
#    (...)
#     307     "TPI",
#     308 )
# --> 310 error2 = household.FOC_labor(
#     311     r_s,
#     312     w_s,
#     313     p_tilde_s,
#     314     b_s,
#     315     b_splus1,
#     316     n_s,
#     317     bq,
#     318     rm,
#     319     factor,
#     320     tr,
#     321     ubi,
#     322     theta,
#     323     chi_n_s,
#     324     etr_params,
#     325     mtrx_params,
#     326     t,
#     327     j,
#     328     p,
#     329     "TPI",
#     330 )
#     332 # Check and punish constraint violations
#     333 mask1 = n_guess < 0
#
# File c:\Users\Gyumin Kim\anaconda3\Lib\site-packages\ogcore\household.py:644, in FOC_labor(r, w, p_tilde, b, b_splus1, n, bq, rm, factor, tr, ubi, theta, chi_n, etr_params, mtrx_params, t, j, p, method)
#     640     else:
#     641         tax_noncompliance = p.labor_income_tax_noncompliance_rate[
#     642             t : t + length, j
#     643         ]
# --> 644         e_long = np.concatenate(
#     645             (
#     646                 p.e,
#     647                 np.tile(p.e[-1, :, :].reshape(1, p.S, p.J), (p.S, 1, 1)),
#     648             ),
#     649             axis=0,
#     650         )
#     651         e = np.diag(e_long[t : t + p.S, :, j], max(p.S - length, 0))
#     652 else:
#
# KeyboardInterrupt:

# %% [markdown]
# Exercies 17.7 : The Federal Reserve Economic Database (FRED) contains macroeconomic data for a number of countries and a user friendly interface. In addition, tools, such as pandas-datareader make it extremely easy to access the FRED API. In this exercise, use pandas-datareader to download the quarterly, real GDP time series for South Africa from FRED. Plot it.

# %%
"""
Exercise 17.7
-------------
Download quarterly real GDP for South Africa using pandas-datareader
and plot the time series.

FRED Series:
    NGDPRNSAXDCZAQ  =  Real GDP for South Africa (quarterly, chained)

Requirements:
    pip install pandas-datareader
"""

# Install pandas-datareader if needed
# !pip install pandas-datareader

import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader.data import DataReader

# ----------------------------------------
# South Africa's real GDP (quarterly)
# FRED series ID: NGDPRNSAXDCZAQ
# ----------------------------------------
fred_series = "NGDPRNSAXDCZAQ"

# Download GDP data from FRED
gdp_sa = DataReader(fred_series, "fred", start="1990-01-01")

# Remove missing data
gdp_sa = gdp_sa.dropna()

# ----------------------------------------
# Plot the GDP series
# ----------------------------------------
plt.figure(figsize=(10,5))
plt.plot(gdp_sa.index, gdp_sa[fred_series], linewidth=2)

plt.title("Quarterly Real GDP — South Africa (FRED)")
plt.xlabel("Year")
plt.ylabel("Real GDP (chained units)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Display first few observations
gdp_sa.head()
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\gyumin kim\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas-datareader) (5.3.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas-datareader) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas-datareader) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gyumin kim\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gyumin kim\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2025.4.26)
#             NGDPRNSAXDCZAQ
# DATE
# 1993-01-01        560469.5
# 1993-04-01        574145.7
# 1993-07-01        587282.1
# 1993-10-01        593258.5
# 1994-01-01        571211.4

# %% [markdown]
# Exercise 17.8 : Now, use the datetime object functions to collapse the quarterly GDP data to annual data. Plot it.

# %%
"""
Exercise 17.8
-------------
Convert quarterly South Africa real GDP (FRED series)
into annual GDP using datetime resampling, and plot it.
"""

import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader.data import DataReader

# ----------------------------------------
# Load quarterly real GDP for South Africa (from Exercise 17.7)
# FRED ID: NGDPRNSAXDCZAQ
# ----------------------------------------
fred_series = "NGDPRNSAXDCZAQ"
gdp_q = DataReader(fred_series, "fred", start="1990-01-01").dropna()

# ----------------------------------------
# Convert quarterly GDP → annual GDP
# We aggregate by summing four quarters
# ----------------------------------------
gdp_annual = gdp_q.resample("A").sum()   # A = year-end frequency
gdp_annual.index = gdp_annual.index.year  # convert datetime → year integers

# ----------------------------------------
# Plot annual GDP
# ----------------------------------------
plt.figure(figsize=(10,5))
plt.plot(gdp_annual.index, gdp_annual[fred_series], marker="o")
plt.title("Annual Real GDP — South Africa (Converted from Quarterly FRED Data)")
plt.xlabel("Year")
plt.ylabel("Annual Real GDP (sum of 4 quarters)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Display first rows
gdp_annual.head()
# Out:
# C:\Users\Gyumin Kim\AppData\Local\Temp\ipykernel_19716\2028663220.py:23: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   gdp_annual = gdp_q.resample("A").sum()   # A = year-end frequency
#       NGDPRNSAXDCZAQ
# DATE
# 1993       2315155.8
# 1994       2389240.8
# 1995       2463307.2
# 1996       2569229.5
# 1997       2636029.4

# %% [markdown]
# Exercise 17.9 : With your annual data, compute the annual growth rate for each year. Plot the time series of growth rates.

# %%
"""
Exercise 17.9
-------------
Compute annual real GDP growth rates for South Africa
using the annual GDP series from Exercise 17.8,
and plot the growth-rate time series.
"""

import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader.data import DataReader

# ----------------------------------------
# Step 1: Load quarterly GDP data from FRED
# ----------------------------------------
fred_series = "NGDPRNSAXDCZAQ"
gdp_q = DataReader(fred_series, "fred", start="1990-01-01").dropna()

# ----------------------------------------
# Step 2: Convert quarterly GDP → annual GDP
# Aggregate by summing the four quarters of each year.
# ----------------------------------------
gdp_annual = gdp_q.resample("A").sum()
gdp_annual.index = gdp_annual.index.year   # simplify index to integer years

# ----------------------------------------
# Step 3: Compute annual GDP growth rate
# Growth_t = (Y_t / Y_{t-1}) - 1
# Multiply by 100 to convert to percent.
# ----------------------------------------
gdp_growth = gdp_annual.pct_change() * 100
gdp_growth = gdp_growth.dropna()   # drop the first NaN growth observation

# ----------------------------------------
# Step 4: Plot annual GDP growth rate
# ----------------------------------------
plt.figure(figsize=(10,5))
plt.plot(gdp_growth.index, gdp_growth[fred_series], marker='o')

plt.title("Annual Real GDP Growth Rate — South Africa")
plt.xlabel("Year")
plt.ylabel("Growth Rate (%)")
plt.grid(True)
plt.tight_layout()
plt.show()

# Display the first few annual growth observations
gdp_growth.head()
# Out:
# C:\Users\Gyumin Kim\AppData\Local\Temp\ipykernel_19716\2887596454.py:23: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   gdp_annual = gdp_q.resample("A").sum()
#       NGDPRNSAXDCZAQ
# DATE
# 1994        3.200001
# 1995        3.099997
# 1996        4.300004
# 1997        2.599997
# 1998        0.500002

# %% [markdown]
# Exercise 17.10 : Now let’s estimate the autocorrelation in GDP growth, assuming is a first order autoregressive process (AR1). We’ll do this with the statsmodles.OLS function. First, create a new column in your data frame that is the lagged value of GDP growth. Then, use the statsmodels.regression.linear_model.OLS function to estimate the following equation: What did you estimate as ? What does this represent? How persistent is the growth process in South Africa?

# %%
"""
Exercise 17.10
Estimate AR(1) autocorrelation in South Africa's annual GDP growth using:

    statsmodels.regression.linear_model.OLS

Steps:
 1. Download quarterly real GDP (SA).
 2. Convert to annual GDP.
 3. Compute annual growth rate.
 4. Create lagged growth column.
 5. Estimate AR(1): g_t = α + φ g_{t-1} + ε_t
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader.data import DataReader
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

# ---------------------------------------
# 1. Download quarterly real GDP (SA)
# ---------------------------------------
fred_series = "NGDPRNSAXDCZAQ"
gdp_q = DataReader(fred_series, "fred", start="1990-01-01").dropna()

# ---------------------------------------
# 2. Convert to annual GDP (sum of 4 quarters)
# ---------------------------------------
gdp_annual = gdp_q.resample("A").sum()
gdp_annual.index = gdp_annual.index.year   # convert to year integers

# ---------------------------------------
# 3. Compute annual GDP growth (%)
# ---------------------------------------
gdp_growth = gdp_annual.pct_change() * 100
gdp_growth = gdp_growth.dropna()

# ---------------------------------------
# 4. Prepare AR(1) regression dataset
# ---------------------------------------
df = pd.DataFrame({"g": gdp_growth[fred_series]})
df["g_lag"] = df["g"].shift(1)
df = df.dropna()

Y = df["g"]
X = sm.add_constant(df["g_lag"])  # add intercept

# ---------------------------------------
# 5. Estimate AR(1) using OLS
# ---------------------------------------
model = OLS(Y, X).fit()

phi_hat = model.params["g_lag"]

print("Estimated AR(1) φ =", round(phi_hat, 4))
print("\n=== Regression Summary ===")
print(model.summary())

# ---------------------------------------
# 6. Plot growth series + lag for visualization
# ---------------------------------------
plt.figure(figsize=(10,5))
plt.plot(df.index, df["g"], label="GDP Growth (%)")
plt.plot(df.index, df["g_lag"], label="Lagged GDP Growth (%)", alpha=0.6)
plt.legend()
plt.grid(True)
plt.title("South Africa Annual GDP Growth and Lagged Growth")
plt.xlabel("Year")
plt.ylabel("Growth (%)")
plt.show()
# Out:
# Estimated AR(1) φ = 1.0779
#
# === Regression Summary ===
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      g   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9268
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):              0.344
# Time:                        22:21:08   Log-Likelihood:                -125.14
# No. Observations:                  31   AIC:                             254.3
# Df Residuals:                      29   BIC:                             257.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.7173      3.629     -0.749      0.460     -10.140       4.706
# g_lag          1.0779      1.120      0.963      0.344      -1.212       3.368
# ==============================================================================
# Omnibus:                       70.008   Durbin-Watson:                   1.115
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              835.211
# Skew:                          -4.892   Prob(JB):                    4.33e-182
# Kurtosis:                      26.471   Cond. No.                         4.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\Gyumin Kim\AppData\Local\Temp\ipykernel_19716\2659083609.py:31: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   gdp_annual = gdp_q.resample("A").sum()

# %% [markdown]
# Answers 17.10 :
#
# (1) What did you estimate the alpha as?
# This means that if last year's growth were 0%, the model predicts –2.7% growth this year. This is a negative growth drift, which is unusual but not impossible for emerging markets with volatile data or short samples. Economically, a negative alpha suggests that over the sample period, trend annual growth was low or declining.
#
# (2) What does the constant represent?
# The constant alpha represetns the baseline or trend component of GDP growth after accouting for last year's growth. It reflects a sample-specific correction term in a dataset that behaves almost like a random walk with drift.
#
# (3) How persistent is the growth process in South Africa?
# My estimate is 1.0779. A estimate greater than 1 means explosive persistence. GDP growth is behaving like a non-stationary or near-unit-root process. A shock to GDP growth does not die out. Therefore, South Africa's growth is highly volatile, which is appropriate given that they are developing countries in Africa.

# %% [markdown]
# Exercise 17.11 : Use income.py from OG-USA to retrieve the earnings process matrix. Read through the docstrings of each function to see which to use. With the e matrix that is returned, create a line plot of the earnings at each age for the J different types.

# %%
"""
Exercise 17.11
--------------
Use income.py from OG-USA to retrieve the earnings-process matrix e(s,j)
and plot earnings at each age for all J ability types.

The earnings matrix e_orig returned has shape (S, J):
   S = number of ages (80: ages 21–100)
   J = number of lifetime ability types (7)
"""

import numpy as np
import matplotlib.pyplot as plt

# Import functions from your downloaded OG-USA income.py file
from income import get_e_orig

# ----------------------------------------------------
# Step 1: Define demographic weights needed by get_e_orig
# ----------------------------------------------------
S = 80          # ages 21–100 → 80 model periods
J = 7           # number of lifetime ability groups

# Age weights (uniform across ages 21–100)
age_wgts_80 = np.ones(S) / S

# Ability/population weights for 7 ability types
abil_wgts_7 = np.array([0.25, 0.25, 0.20, 0.10, 0.10, 0.09, 0.01])

# ----------------------------------------------------
# Step 2: Retrieve the original earnings matrix e_orig(s,j)
# ----------------------------------------------------
e_orig = get_e_orig(age_wgts_80, abil_wgts_7)

print("Shape of e_orig:", e_orig.shape)   # Expect (80, 7)

# ----------------------------------------------------
# Step 3: Plot earnings profiles by age for each ability type
# ----------------------------------------------------
ages = np.arange(21, 101)   # actual ages corresponding to rows

plt.figure(figsize=(10,6))

for j in range(J):
    plt.plot(ages, e_orig[:, j], label=f"Ability type {j+1}")

plt.title("Earnings Process e(s,j) Using OG-USA income.py")
plt.xlabel("Age (21–100)")
plt.ylabel("Relative Earnings Ability")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Shape of e_orig: (80, 7)

# %% [markdown]
# Exercise 17.12 : Now we’re going to adjust the above earnings process to match the Gini coefficient in a country that isn’t the U.S. (note that the Gini coefficient for income in the U.S. was 41.5 in 2019). The transformation we’ll make is: where represents the country of interest. We will find by matching the Gini coefficient in the country of interest. To do this, we’ll use the scipy.optimize module. First, create a function that takes as an  argument and returns the Gini coefficient in the country of interest (hint: the ogusa.utils.Inequality class object will be helpful here). Then, use the scipy.optimize.minimize_scalar function to find the value of that minimizes the difference between the Gini coefficient in the country of interest and the Gini coefficient in the U.S. Finally, use the value of you found to transform the e matrix from the U.S. to the country of interest. Plot the earnings processes in the U.S. and the country of interest. How do they differ?

# %%
"""
Exercise 17.12 — Adjust earnings process to match a country's Gini
------------------------------------------------------------------
We adjust the U.S. earnings matrix e(s,j) by applying a nonlinear
transformation e_country = e_US ** theta so that the earnings-induced
Gini coefficient matches a target country’s Gini.
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize_scalar
from income import get_e_orig   # OG-USA earnings process
from ogusa_utils import Inequality

# ------------------------------------------------------------
# Step 1: Load U.S. earnings matrix e(s,j) from income.py
# ------------------------------------------------------------
S = 80
J = 7

age_wgts = np.ones(S) / S
abil_wgts = np.array([0.25, 0.25, 0.20, 0.10, 0.10, 0.09, 0.01])

# Load OG-USA original earnings matrix
e_US = get_e_orig(age_wgts, abil_wgts)   # shape (80,7)
print("Earnings matrix shape:", e_US.shape)

# ------------------------------------------------------------
# Step 2: Function to compute Gini using OG-USA Inequality class
# ------------------------------------------------------------
def compute_gini(e_matrix):
    ineq = Inequality(
        dist=e_matrix,
        pop_weights=age_wgts,
        ability_weights=abil_wgts,
        S=S,
        J=J
    )
    return float(ineq.gini())

print("U.S. earnings Gini:", compute_gini(e_US))

# ------------------------------------------------------------
# Step 3: Define Gini(theta) for transformed earnings
# ------------------------------------------------------------
def gini_of_theta(theta):
    theta = float(theta)
    return compute_gini(e_US ** theta)

# ------------------------------------------------------------
# Step 4: Define target country Gini and objective function
# ------------------------------------------------------------
gini_target = 0.45     # Example target country

def objective(theta):
    return (gini_of_theta(theta) - gini_target)**2

# ------------------------------------------------------------
# Step 5: Solve for theta that hits target Gini
# ------------------------------------------------------------
sol = minimize_scalar(objective, bounds=(0.2, 3.0), method="bounded")
theta_hat = sol.x

print("\n====== Optimization Results ======")
print("Converged:", sol.success)
print(f"theta_hat = {theta_hat:.4f}")
print(f"Gini(theta_hat) = {gini_of_theta(theta_hat):.4f}")
print("Target country Gini:", gini_target)

# ------------------------------------------------------------
# Step 6: Construct transformed earnings matrix
# ------------------------------------------------------------
e_country = e_US ** theta_hat

# ------------------------------------------------------------
# Step 7: Plot earnings profiles
# ------------------------------------------------------------
ages = np.linspace(21, 100, S)

plt.figure(figsize=(10,6))
for j in range(J):
    plt.plot(ages, e_US[:, j], label="U.S." if j == 0 else "", color="blue", alpha=0.5)
    plt.plot(ages, e_country[:, j], "--", label="Adjusted" if j == 0 else "", color="red", alpha=0.7)

plt.title(f"Earnings Profiles: U.S. vs. Adjusted (theta = {theta_hat:.3f})")
plt.xlabel("Age")
plt.ylabel("Earnings Ability")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Earnings matrix shape: (80, 7)
# U.S. earnings Gini: 0.3939415031808835
#
# ====== Optimization Results ======
# Converged: True
# theta_hat = 1.1548
# Gini(theta_hat) = 0.4500
# Target country Gini: 0.45

# %% [markdown]
# Answers 17.2 :
#
# The transformed earnings profiles differ from the U.S. profiles because the estimated θ = 1.155 is greater than one. This amplifies earnings for higher-ability types much more than for lower-ability types. As a result, the vertical distance between ability groups becomes larger, especially near peak working ages. The age-earnings shape (the hump around ages 50–60) remains essentially the same, but it is scaled upward for high-ability households. The earnings distribution for the country of interest is therefore more unequal than that of the U.S., consistent with its higher Gini coefficient. In short, higher-ability individuals earn considerably more relative to lower-ability individuals, generating a steeper and more unequal earnings process.
